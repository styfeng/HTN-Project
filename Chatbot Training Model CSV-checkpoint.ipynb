# %%
# things we need for NLP
import nltk
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()
from nltk.corpus import wordnet
syns = wordnet.synsets("program")

# things we need for Tensorflow
import numpy as np
import tflearn
import tensorflow as tf
import random
import re
import unicodedata
import sys

# %%
import urllib.request
import urllib.response
import sys
import os, glob
import http.client, urllib
import json
import http.client, urllib.request, urllib.parse, urllib.error, base64

# Replace the accessKey string value with your valid access key.
accessKey = '82e4612615634c398bfd26e7d6327833'
url = 'westcentralus.api.cognitive.microsoft.com'
path = '/text/analytics/v2.0/keyPhrases'

def extract_keywords(body):
    headers = {'Ocp-Apim-Subscription-Key': accessKey}
    conn = http.client.HTTPSConnection(url)
    body_req = {'documents':[{'language': 'en', 'id': 1, 'text': body}]}
    body_json = json.dumps(body_req)
    conn.request ("POST", path, body_json, headers)
    response = conn.getresponse ()
    string = response.read().decode('utf-8')
    json_obj = json.loads(string)
    print("json_obj: ", json_obj)
    keyphrases_list = ((json_obj['documents'])[0])['keyPhrases']
    print("keyphrases_list: ", keyphrases_list)
    return keyphrases_list

# %%
# medical conditions training data
training_data = []

import csv

# adds every medical condition along with associated info from csv file
with open('Disease CSV.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count != 0:
            training_data.append({"class":row[1], "synonyms":row[2], 
                                  "sentence":row[3], "treatments":row[4], "danger level":row[5]})
        line_count += 1

print ("%s total classes in training data" % len(training_data))

for term in training_data:
    print(term["class"] + " | " + term["synonyms"] + " | " + term["sentence"] + 
          " | " + term["treatments"] + " | " + term["danger level"])
# Out:
# 28 total classes in training data
# Common Cold | Upper Respiratory Tract;Nose and Throat Infection | Runny or stuffy nose;sore throat;cough;congestion;body aches;sneezing | Stay hydrated;rest;sooth a sore throat using saltwater gargle;take over the counter cold and cough medications
#  | 1
# Allergies | Allergic Reaction | Eye irritation;runny or stuffy nose;puffy watery eyes;sneezing;inflamed;itchy nose and throat | Remove the cause of allergy;
# otherwise take Antihistamines to relieve sneezing;Decongestants to relieve congestions in nasal membranes;Anti inflamary agents to reduce;Allergy shots | 1
# Conjunctivitis | Pink Eye | Redness of eyes;itchy eyes;tearing or burning sensation of eyeball | See a doctor;Bacterial cases can be treated with antibiotic eye drops;Allergic reactions can be treated with other eye drops | 1
# Irritable Bowel Syndrome (IBS) | Diarrhea | Watery, loose stools;frequent bowel movement;stomachache nausea;bloody stool | Diarrhea will typically go away in 2 days;Consult a physician if you experience severe stomach or rectum pain, fever, or diarrhea lasting longer than 3 days | 1
# Acute Headache  | migraine;Headache  | Intense pain from oneside, then spreads. Often lasting a few hours, accompanied by nausea  | Sleep and rest;Icepack over eyes or head;Moderate use of OTC medicines such as acetaminophen, aspirin, or ibuprofen may relieve pain | 1
# Chronic Headache  | Tension type;Headache  | Constant, dull pain of head;can last from half an hour to several days | Sleep and rest;icepack over eyes or head;Note: overuse of pain relieving medicines may result in "analgesic rebound headaches" | 1
# Intestinal Gas | Stomach Ache | Stomach pain due to gas;caused by swallowed air;breakdown of undigested food | Take digestive enzyme supplements, such as Beano and lactase supplements;Eat several small meals throughout the day instead of two or three large ones;Take a stroll after each meal | 1
# Nausea and Vomiting | Labrynthitis;Stomach ulcers;Hepatitis;Meningitis | Abdominal cramps;watery diarrhea and nausea;vomiting | Most cases resolve within a couple days without treatments;Avoid food and water that may be contaminated;Wash your hands thoroughly and frequently;Avoid sharing eating utencils | 1
# E Coli Infection |  | nausea;vomiting;headache;mild fever;severe stomach cramps; watery;bloody diarrhea | Visit a hospital immediately | 1
# Chlamydia | Sexually Transmitted Infection (STI) | vaginal discharge;burning sensation during urinating;pain in the lower abdomen;pain during sex;vaginal bleeding between periods or after intercourse;discharge from penis;burning or itching at the opening of the penis;pain or swelling in the testicles | See a professional doctor;Use Azithromycin or Doxycycline | 4
# Influenza | Flu | high fever;cough;muscle aches;headache;chills;loss of appetite;chills;fatigue;sore throat; runny or stuffy nose; stomach ache;diarrhea;vomiting | Mild flu treated with rest and fluids; See a doctor in the case of severe flu | 1
# Hepatitis B | Herpes | sores on the penis;sores near the vagina;tender lumps in the groin | See a doctor immediately;Take antiviral drugs | 6
# HBV;Liver infection |  | Fever;Fatigue;Loss of appetite;Nausea;Vomiting;Abdominal pain;Dark urine;Clay-colored bowel movement;joint pain;Jaundice | See a doctor immediately;Take antiviral drugs for chronic HBV;No medication is availiable for acute infection | 5
# Avian Influenza | H5N1 | high fever;cough;aching muscles;sore throat;stomach pain;chest pain;diarrhea;difficulty breathing;pneumonia;acute respiratory distress syndrome | Seek help from a professional healthcare provider immediately | 9
# Swine Influenza | H1N1 | Fever;cough;sore throat;runny nose;stuffy nose;watery eyes;red eyes;body aches;headache;fatigue;diarrhea;nausea;vomiting | Recommended medicines for swine influenza are oseltamivir, peramivir, and zanamivir | 8
# Dermatitis |  | Localized inflammation of the skin;redness;heat;swelling;pain | Compress;corticosteroid cream;calcineurin inhibitors;See a doctor for further assistance | 1
# West Nile Virus |  | fever;headache;body aches;mild rash;swollen lymph glands;rapid onset of severe headache;high fever;stiff neck;nausea or vomiting;difficulty swallowing;drowsiness;confusion;loss of consciousness;lack of coordination;muscle weakness;paralysis | Please see a healthcare professional;There are no specific treatments for West Nile Virus in humans | 8
# Zika Virus |  | red eyes;weakness;headaches;lack of energy;joint swelling;low grade or simple or mild fever;red rash | Get plenty of rest;drink fluid;take medicine such as acetaminophen;Consult with a professional doctor | 4
# Chickenpox | Varicella Zoster Virus | fever;aching muscles;loss of appetite;rash;spots;blisters;clouding;mouth soreness;itchiness | Drink plenty of fluid;Take Tylenol;Consult with a doctor | 2
# Alzheimer |  | Memory loss;challenge in planning or solving problems;difficulty completing familiar tasks;confusion in time or place;difficulties understanding visual images and spatial relationships;problems in speaking or writing;misplacing things;decreased judgement;withdrawal from activities;change in personality | Cholinesterase inhibitors;Memantine(Namenda);Please consult with a professional doctor | 4
# Pregrancy |  | Tender,swollen breats;fatigue;slight bleeding or cramping;missing period;bloating;constipation;crying;gas;mood swings;lower back pain | You are pregnant! Remember to take your prenatal vitamin;quit smoking;stop drinking alcohol;cut down on caffeine; avoid hazardous foods;eat well and sleep well! | 2
# Stroke |  | sudden numbness or weakness of the face, arm or leg;sudden confusion;sudden trouble seeing;sudden dizziness | See a healthcare professional immediately | 9
# Eating Disorders including Anorexia & Bulimia Nervosa |  | Chronic restrictive eating or dieting;rapid loss of weight;obsession with calories and fat contents of food;continued fixation with food;depression;reporting sensation of feeling cold;loss or thinning of hair | Seek help from a therapist, physician, and nutritionist | 3
# Coronary Heart Disease |  | chest pain;indigestion;heatburn;weak nausea;cramping;shortness of breath | quit smoking;have a healthy diet;exercise regularly;consult with a doctor | 7
# Sleep Apnea |  | Waking up sore;dry throat;loud snoring;sleepiness or lack of energy during the day;morning headaches;restless sleep;forgetfulness;mood change;recurrent awakening | Losing weight;avoiding alcohol and sleeping pills;changing sleeping position to improve breathing;stop smoking;avoid sleeping on your back | 5
# Crohn's Disease |  | diarrhea;fever;fatigue;abdominal pain and cramping;blood in your stool;mouth sores;reduced appetite and weight loss;pain or drainage near or around the anus | If you have persistent changes in your bowel habits or have the following conditions, see a doctor: Abdominal pain;blood in your stool;ongoing bouts of diarrhea that don't respond to OTC medication;unexplained fever lasting over two days;unexplained weight loss | 4
# Breast Cancer |  | pain in the armpist or breast that does not change with the monthly cycle;redness of the skin of the breast;rash around the nipples;discharge from a nipple;sunken or inverted nipple;change in the size of breast;change the shape of the breast;peeling flaking or scaling of the skin on the breast or nipple | You may have breast cancer, please consult with a doctor and conduct further diagnostics at your local hospital | 10
# Prostate Cancer |  | frequent urges to urinate;difficulty commencing and maintaining urination;blood in the urine;painful urination and ejaculation;difficulty achieving or maintaining an erection | You may have prostate cancer, please consult with a doctor and conduct further diagnostics at your local hospital | 10

# %%
# a table structure to hold the different punctuation used
tbl = dict.fromkeys(i for i in range(sys.maxunicode)
                    if unicodedata.category(chr(i)).startswith('P'))

# method to remove punctuations from sentences.
def remove_punctuation(text):
     return text.translate(tbl)

# method to slice strings
def slicer(my_str,sub):
    index=my_str.find(sub)
    if index !=-1 :
         return my_str[index:] 
    else :
         raise Exception('Sub string not found!')

# find synonyms of all the words in a sentence
def find_syns(sentence):
    words = []
    for word in sentence.split():
        if word != '':
            synonyms = []
            for syn in wordnet.synsets(word):
                for l in syn.lemmas():
                    if l.name() not in synonyms and l.name() != word:
                        synonyms.append(l.name())
            word = (word + ' ' + ' '.join(synonyms)).strip()
            words.append(word)
    print("SYNONYMS:",words)
    return words

# clean all synonyms and words
def clean_syns(arg):
    clean_synonyms = []
    for syn_set in synonyms:
        syn_set = ' '.join(s for s in syn_set.split() if not any(c.isdigit() for c in s))
        syn_set = re.sub(r'\d+', '', syn_set)
        syn_set = syn_set.replace("_"," ")
        syn_set = remove_punctuation(syn_set)
        clean_synonyms.append(syn_set)
    print("CLEAN SYNONYMS: ",clean_synonyms)
    return clean_synonyms

# %%
import string

words = []
words_total = []
classes = []
classes_details = []
documents = []
ignore_words = ['?']

# loop through each description per symptom
for pattern in training_data:
    symptoms = pattern['sentence']
    word_list = symptoms.split(';')
    print("WORD_LIST:",word_list)
    word_list_new = []
    for word in word_list:
        word = remove_punctuation(word)
        word = word.strip().lower()
        word_list_new.append(word)
    print("WORD_LIST_NEW:",word_list_new)
    joined_symps = ' '.join(s for s in word_list_new)
    print("joined_symps:",joined_symps)
    
    #find synonyms of each word in description
    synonyms = find_syns(joined_symps)
    synonyms_clean = clean_syns(synonyms)
    
    # tokenize each word in the description
    w_list = []
    for syn_set in synonyms_clean:
        w_token = nltk.word_tokenize(syn_set)
        w = [stemmer.stem(i.lower()) for i in w_token if i not in ignore_words]
        w = sorted(list(set(w)))
    
        # strip duplicates
        for item in w:
            if not item in words_total and item != '':
                words_total.append(item.strip())
            else:
                w.remove(item)
    
        w_syn = ' '.join(w)
        w_list.append(w_syn)
    
    #add each string to words
    for item in w_list:
        if not item in words and item != '':
            #print("Item is in words array already.")
            words.append(item.strip())
     
    # add to documents in our corpus
    documents.append((w_list, pattern['class']))
    
    # add to our classes list
    if pattern['class'] not in classes:
        classes.append(pattern['class'])
        classes_details.append({"class":pattern['class'], "synonyms":pattern['synonyms'],
                                "treatments":pattern['treatments'], "danger level":pattern['danger level']})
        
#remove duplicates in words
words = sorted(list(set(words)))

# remove duplicates in classes
classes = sorted(list(set(classes)))

print (len(documents), "documents", documents)
print (len(classes), "classes", classes)
print (len(words), "unique stemmed words", words)
print ("classes_details", classes_details)
# Out:
# WORD_LIST: ['Runny or stuffy nose', 'sore throat', 'cough', 'congestion', 'body aches', 'sneezing']
# WORD_LIST_NEW: ['runny or stuffy nose', 'sore throat', 'cough', 'congestion', 'body aches', 'sneezing']
# joined_symps: runny or stuffy nose sore throat cough congestion body aches sneezing
# SYNONYMS: ['runny fluid', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'stuffy airless close unaired stodgy', 'nose olfactory_organ nozzle intrude horn_in pry poke scent wind nuzzle', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'cough coughing', 'congestion over-crowding', 'body organic_structure physical_structure dead_body torso trunk consistency consistence eubstance soundbox personify', 'aches ache aching hurt suffer yearn yen pine languish smart', 'sneezing sneeze sternutation']
# CLEAN SYNONYMS:  ['runny fluid', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'stuffy airless close unaired stodgy', 'nose olfactoryorgan nozzle intrude hornin pry poke scent wind nuzzle', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'cough coughing', 'congestion overcrowding', 'body organicstructure physicalstructure deadbody torso trunk consistency consistence eubstance soundbox personify', 'aches ache aching hurt suffer yearn yen pine languish smart', 'sneezing sneeze sternutation']
# WORD_LIST: ['Eye irritation', 'runny or stuffy nose', 'puffy watery eyes', 'sneezing', 'inflamed', 'itchy nose and throat']
# WORD_LIST_NEW: ['eye irritation', 'runny or stuffy nose', 'puffy watery eyes', 'sneezing', 'inflamed', 'itchy nose and throat']
# joined_symps: eye irritation runny or stuffy nose puffy watery eyes sneezing inflamed itchy nose and throat
# SYNONYMS: ['eye oculus optic center centre middle heart eyeball', 'irritation annoyance vexation botheration pique temper excitation innervation discomfort soreness aggravation provocation annoying', 'runny fluid', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'stuffy airless close unaired stodgy', 'nose olfactory_organ nozzle intrude horn_in pry poke scent wind nuzzle', 'puffy bouffant intumescent tumescent tumid turgid gusty', 'watery reeking washy weak', 'eyes eye oculus optic center centre middle heart eyeball', 'sneezing sneeze sternutation', 'inflamed inflame kindle enkindle conflagrate stir_up wake ignite heat fire_up ablaze reddened', 'itchy antsy fidgety fretful', 'nose olfactory_organ nozzle intrude horn_in pry poke scent wind nuzzle', 'and', 'throat pharynx']
# CLEAN SYNONYMS:  ['eye oculus optic center centre middle heart eyeball', 'irritation annoyance vexation botheration pique temper excitation innervation discomfort soreness aggravation provocation annoying', 'runny fluid', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'stuffy airless close unaired stodgy', 'nose olfactoryorgan nozzle intrude hornin pry poke scent wind nuzzle', 'puffy bouffant intumescent tumescent tumid turgid gusty', 'watery reeking washy weak', 'eyes eye oculus optic center centre middle heart eyeball', 'sneezing sneeze sternutation', 'inflamed inflame kindle enkindle conflagrate stirup wake ignite heat fireup ablaze reddened', 'itchy antsy fidgety fretful', 'nose olfactoryorgan nozzle intrude hornin pry poke scent wind nuzzle', 'and', 'throat pharynx']
# WORD_LIST: ['Redness of eyes', 'itchy eyes', 'tearing or burning sensation of eyeball']
# WORD_LIST_NEW: ['redness of eyes', 'itchy eyes', 'tearing or burning sensation of eyeball']
# joined_symps: redness of eyes itchy eyes tearing or burning sensation of eyeball
# SYNONYMS: ['redness inflammation rubor red', 'of', 'eyes eye oculus optic center centre middle heart eyeball', 'itchy antsy fidgety fretful', 'eyes eye oculus optic center centre middle heart eyeball', 'tearing lacrimation lachrymation watering tear rupture snap bust shoot shoot_down charge buck pluck pull deplume deplumate displume fierce vehement violent trigger-happy', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'burning combustion burn electrocution burning_at_the_stake fire burn_down glow combust bite sting incinerate cauterize cauterise sunburn cut burn_off burn_up', 'sensation esthesis aesthesis sense_experience sense_impression sense_datum ace adept champion maven mavin virtuoso genius hotshot star superstar whiz whizz wizard wiz sense sentience sentiency sensory_faculty', 'of', 'eyeball orb eye']
# CLEAN SYNONYMS:  ['redness inflammation rubor red', 'of', 'eyes eye oculus optic center centre middle heart eyeball', 'itchy antsy fidgety fretful', 'eyes eye oculus optic center centre middle heart eyeball', 'tearing lacrimation lachrymation watering tear rupture snap bust shoot shootdown charge buck pluck pull deplume deplumate displume fierce vehement violent triggerhappy', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'burning combustion burn electrocution burningatthestake fire burndown glow combust bite sting incinerate cauterize cauterise sunburn cut burnoff burnup', 'sensation esthesis aesthesis senseexperience senseimpression sensedatum ace adept champion maven mavin virtuoso genius hotshot star superstar whiz whizz wizard wiz sense sentience sentiency sensoryfaculty', 'of', 'eyeball orb eye']
# WORD_LIST: ['Watery, loose stools', 'frequent bowel movement', 'stomachache nausea', 'bloody stool']
# WORD_LIST_NEW: ['watery loose stools', 'frequent bowel movement', 'stomachache nausea', 'bloody stool']
# joined_symps: watery loose stools frequent bowel movement stomachache nausea bloody stool
# SYNONYMS: ['watery reeking washy weak', 'loose free liberate release unloose unloosen unleash let_loose loosen relax informal liberal lax unaffixed slack open idle at_large escaped on_the_loose easy light promiscuous sluttish wanton', 'stools stool fecal_matter faecal_matter feces faeces BM ordure dejection toilet can commode crapper pot potty throne tiller defecate shit take_a_shit take_a_crap ca-ca crap make', 'frequent patronize patronise shop shop_at buy_at sponsor haunt', 'bowel intestine gut', 'movement motion move motility social_movement front campaign cause crusade drive effort apparent_motion apparent_movement bowel_movement bm drift trend', 'stomachache stomach_ache bellyache gastralgia', 'nausea sickness', 'bloody bally blinking blooming crashing flaming fucking damn all-fired', 'stool fecal_matter faecal_matter feces faeces BM ordure dejection toilet can commode crapper pot potty throne tiller defecate shit take_a_shit take_a_crap ca-ca crap make']
# CLEAN SYNONYMS:  ['watery reeking washy weak', 'loose free liberate release unloose unloosen unleash letloose loosen relax informal liberal lax unaffixed slack open idle atlarge escaped ontheloose easy light promiscuous sluttish wanton', 'stools stool fecalmatter faecalmatter feces faeces BM ordure dejection toilet can commode crapper pot potty throne tiller defecate shit takeashit takeacrap caca crap make', 'frequent patronize patronise shop shopat buyat sponsor haunt', 'bowel intestine gut', 'movement motion move motility socialmovement front campaign cause crusade drive effort apparentmotion apparentmovement bowelmovement bm drift trend', 'stomachache stomachache bellyache gastralgia', 'nausea sickness', 'bloody bally blinking blooming crashing flaming fucking damn allfired', 'stool fecalmatter faecalmatter feces faeces BM ordure dejection toilet can commode crapper pot potty throne tiller defecate shit takeashit takeacrap caca crap make']
# WORD_LIST: ['Intense pain from oneside, then spreads. Often lasting a few hours, accompanied by nausea ']
# WORD_LIST_NEW: ['intense pain from oneside then spreads often lasting a few hours accompanied by nausea']
# joined_symps: intense pain from oneside then spreads often lasting a few hours accompanied by nausea
# SYNONYMS: ['intense acute vivid', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'from', 'oneside', 'then so and_so and_then', 'spreads spread spreading gap ranch cattle_ranch cattle_farm scatter paste banquet feast spread_head spreadhead facing_pages bedspread bedcover bed_cover bed_covering counterpane distribute propagate overspread unfold spread_out open circulate circularize circularise disseminate broadcast diffuse disperse pass_around go_around fan_out', 'often frequently oftentimes oft ofttimes much a_great_deal', 'lasting last endure survive live live_on go hold_up hold_out permanent durable long-lasting long-lived persistent', 'a angstrom angstrom_unit A vitamin_A antiophthalmic_factor axerophthol deoxyadenosine_monophosphate adenine ampere amp type_A group_A', 'few', 'hours hour hr 60_minutes time_of_day minute', 'accompanied attach_to accompany come_with go_with play_along follow company companion keep_company attended', 'by past aside away', 'nausea sickness']
# CLEAN SYNONYMS:  ['intense acute vivid', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'from', 'oneside', 'then so andso andthen', 'spreads spread spreading gap ranch cattleranch cattlefarm scatter paste banquet feast spreadhead spreadhead facingpages bedspread bedcover bedcover bedcovering counterpane distribute propagate overspread unfold spreadout open circulate circularize circularise disseminate broadcast diffuse disperse passaround goaround fanout', 'often frequently oftentimes oft ofttimes much agreatdeal', 'lasting last endure survive live liveon go holdup holdout permanent durable longlasting longlived persistent', 'a angstrom angstromunit A vitaminA antiophthalmicfactor axerophthol deoxyadenosinemonophosphate adenine ampere amp typeA groupA', 'few', 'hours hour hr timeofday minute', 'accompanied attachto accompany comewith gowith playalong follow company companion keepcompany attended', 'by past aside away', 'nausea sickness']
# WORD_LIST: ['Constant, dull pain of head', 'can last from half an hour to several days']
# WORD_LIST_NEW: ['constant dull pain of head', 'can last from half an hour to several days']
# joined_symps: constant dull pain of head can last from half an hour to several days
# SYNONYMS: ['constant constant_quantity invariable changeless invariant unvarying ceaseless incessant never-ending perpetual unceasing unremitting', 'dull muffle mute damp dampen tone_down numb benumb blunt pall muffled muted softened boring deadening ho-hum irksome slow tedious tiresome wearisome dense dim dumb obtuse sluggish thudding leaden', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'of', 'head caput mind brain psyche nous chief top_dog fountainhead headspring head_word capitulum principal school_principal head_teacher promontory headland foreland forefront pass straits headway point question heading header read/write_head drumhead oral_sex lead head_up steer maneuver manoeuver manoeuvre direct guide channelize channelise', 'can tin tin_can canful can_buoy buttocks nates arse butt backside bum buns fundament hindquarters hind_end keister posterior prat rear rear_end rump stern seat tail tail_end tooshie tush bottom behind derriere fanny ass toilet commode crapper pot potty stool throne lavatory lav john privy bathroom put_up displace fire give_notice dismiss give_the_axe send_away sack force_out give_the_sack terminate', "last stopping_point finale finis finish conclusion close death end final_stage shoemaker's_last cobbler's_last endure survive live live_on go hold_up hold_out concluding final terminal net utmost last-place lowest lastly in_conclusion finally", 'from', 'half one-half', 'an Associate_in_Nursing AN', 'hour hr 60_minutes time_of_day minute', 'to', 'several respective various', 'days years day twenty-four_hours twenty-four_hour_period 24-hour_interval solar_day mean_solar_day daytime daylight sidereal_day Day Clarence_Day Clarence_Shepard_Day_Jr.']
# CLEAN SYNONYMS:  ['constant constantquantity invariable changeless invariant unvarying ceaseless incessant neverending perpetual unceasing unremitting', 'dull muffle mute damp dampen tonedown numb benumb blunt pall muffled muted softened boring deadening hohum irksome slow tedious tiresome wearisome dense dim dumb obtuse sluggish thudding leaden', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'of', 'head caput mind brain psyche nous chief topdog fountainhead headspring headword capitulum principal schoolprincipal headteacher promontory headland foreland forefront pass straits headway point question heading header readwritehead drumhead oralsex lead headup steer maneuver manoeuver manoeuvre direct guide channelize channelise', 'can tin tincan canful canbuoy buttocks nates arse butt backside bum buns fundament hindquarters hindend keister posterior prat rear rearend rump stern seat tail tailend tooshie tush bottom behind derriere fanny ass toilet commode crapper pot potty stool throne lavatory lav john privy bathroom putup displace fire givenotice dismiss givetheaxe sendaway sack forceout givethesack terminate', 'last stoppingpoint finale finis finish conclusion close death end finalstage shoemakerslast cobblerslast endure survive live liveon go holdup holdout concluding final terminal net utmost lastplace lowest lastly inconclusion finally', 'from', 'half onehalf', 'an AssociateinNursing AN', 'hour hr timeofday minute', 'to', 'several respective various', 'days years day twentyfourhours twentyfourhourperiod solarday meansolarday daytime daylight siderealday Day ClarenceDay ClarenceShepardDayJr']
# WORD_LIST: ['Stomach pain due to gas', 'caused by swallowed air', 'breakdown of undigested food']
# WORD_LIST_NEW: ['stomach pain due to gas', 'caused by swallowed air', 'breakdown of undigested food']
# joined_symps: stomach pain due to gas caused by swallowed air breakdown of undigested food
# SYNONYMS: ['stomach tummy tum breadbasket abdomen venter belly digest endure stick_out bear stand tolerate support brook abide suffer put_up', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'due ascribable imputable referable', 'to', 'gas gaseous_state gasoline gasolene petrol flatulence flatulency accelerator accelerator_pedal gas_pedal throttle gun natural_gas boast tout swash shoot_a_line brag blow bluster vaunt gasconade', 'caused cause do make induce stimulate have get', 'by past aside away', 'swallowed swallow get_down immerse swallow_up bury eat_up take_back unsay withdraw accept live_with', 'air aura atmosphere breeze zephyr gentle_wind tune melody strain melodic_line line melodic_phrase airwave air_travel aviation air_out aerate send broadcast beam transmit publicize publicise bare vent ventilate', 'breakdown dislocation crack-up equipment_failure partitioning', 'of', 'undigested', 'food nutrient solid_food food_for_thought intellectual_nourishment']
# CLEAN SYNONYMS:  ['stomach tummy tum breadbasket abdomen venter belly digest endure stickout bear stand tolerate support brook abide suffer putup', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'due ascribable imputable referable', 'to', 'gas gaseousstate gasoline gasolene petrol flatulence flatulency accelerator acceleratorpedal gaspedal throttle gun naturalgas boast tout swash shootaline brag blow bluster vaunt gasconade', 'caused cause do make induce stimulate have get', 'by past aside away', 'swallowed swallow getdown immerse swallowup bury eatup takeback unsay withdraw accept livewith', 'air aura atmosphere breeze zephyr gentlewind tune melody strain melodicline line melodicphrase airwave airtravel aviation airout aerate send broadcast beam transmit publicize publicise bare vent ventilate', 'breakdown dislocation crackup equipmentfailure partitioning', 'of', 'undigested', 'food nutrient solidfood foodforthought intellectualnourishment']
# WORD_LIST: ['Abdominal cramps', 'watery diarrhea and nausea', 'vomiting']
# WORD_LIST_NEW: ['abdominal cramps', 'watery diarrhea and nausea', 'vomiting']
# joined_symps: abdominal cramps watery diarrhea and nausea vomiting
# SYNONYMS: ['abdominal abdominal_muscle ab', 'cramps spasm cramp muscle_spasm cramp_iron hamper halter strangle', 'watery reeking washy weak', 'diarrhea diarrhoea looseness_of_the_bowels looseness', 'and', 'nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomit_up purge cast sick cat be_sick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throw_up']
# CLEAN SYNONYMS:  ['abdominal abdominalmuscle ab', 'cramps spasm cramp musclespasm crampiron hamper halter strangle', 'watery reeking washy weak', 'diarrhea diarrhoea loosenessofthebowels looseness', 'and', 'nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomitup purge cast sick cat besick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throwup']
# WORD_LIST: ['nausea', 'vomiting', 'headache', 'mild fever', 'severe stomach cramps', ' watery', 'bloody diarrhea']
# WORD_LIST_NEW: ['nausea', 'vomiting', 'headache', 'mild fever', 'severe stomach cramps', 'watery', 'bloody diarrhea']
# joined_symps: nausea vomiting headache mild fever severe stomach cramps watery bloody diarrhea
# SYNONYMS: ['nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomit_up purge cast sick cat be_sick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throw_up', 'headache concern worry vexation head_ache cephalalgia', 'mild meek modest balmy soft', 'fever febrility febricity pyrexia feverishness', 'severe terrible wicked hard knockout austere stark stern spartan dangerous grave grievous serious life-threatening', 'stomach tummy tum breadbasket abdomen venter belly digest endure stick_out bear stand tolerate support brook abide suffer put_up', 'cramps spasm cramp muscle_spasm cramp_iron hamper halter strangle', 'watery reeking washy weak', 'bloody bally blinking blooming crashing flaming fucking damn all-fired', 'diarrhea diarrhoea looseness_of_the_bowels looseness']
# CLEAN SYNONYMS:  ['nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomitup purge cast sick cat besick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throwup', 'headache concern worry vexation headache cephalalgia', 'mild meek modest balmy soft', 'fever febrility febricity pyrexia feverishness', 'severe terrible wicked hard knockout austere stark stern spartan dangerous grave grievous serious lifethreatening', 'stomach tummy tum breadbasket abdomen venter belly digest endure stickout bear stand tolerate support brook abide suffer putup', 'cramps spasm cramp musclespasm crampiron hamper halter strangle', 'watery reeking washy weak', 'bloody bally blinking blooming crashing flaming fucking damn allfired', 'diarrhea diarrhoea loosenessofthebowels looseness']
# WORD_LIST: ['vaginal discharge', 'burning sensation during urinating', 'pain in the lower abdomen', 'pain during sex', 'vaginal bleeding between periods or after intercourse', 'discharge from penis', 'burning or itching at the opening of the penis', 'pain or swelling in the testicles']
# WORD_LIST_NEW: ['vaginal discharge', 'burning sensation during urinating', 'pain in the lower abdomen', 'pain during sex', 'vaginal bleeding between periods or after intercourse', 'discharge from penis', 'burning or itching at the opening of the penis', 'pain or swelling in the testicles']
# joined_symps: vaginal discharge burning sensation during urinating pain in the lower abdomen pain during sex vaginal bleeding between periods or after intercourse discharge from penis burning or itching at the opening of the penis pain or swelling in the testicles
# SYNONYMS: ['vaginal', 'discharge venting emission expelling spark arc electric_arc electric_discharge outpouring run dismissal dismission firing liberation release sack sacking waiver firing_off dispatch complete free fire go_off acquit assoil clear exonerate exculpate exhaust expel eject drop drop_off set_down put_down unload muster_out empty', 'burning combustion burn electrocution burning_at_the_stake fire burn_down glow combust bite sting incinerate cauterize cauterise sunburn cut burn_off burn_up', 'sensation esthesis aesthesis sense_experience sense_impression sense_datum ace adept champion maven mavin virtuoso genius hotshot star superstar whiz whizz wizard wiz sense sentience sentiency sensory_faculty', 'during', 'urinating urinate make piddle puddle micturate piss pee pee-pee make_water relieve_oneself take_a_leak spend_a_penny wee wee-wee pass_water', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'in inch indium In atomic_number_49 Indiana Hoosier_State IN inwards inward', 'the', 'lower lower_berth take_down let_down get_down bring_down lour turn_down depress frown glower low low-toned low-pitched abject low-down miserable scummy scurvy humble lowly modest small depleted broken crushed humbled humiliated gloomy grim blue depressed dispirited down downcast downhearted down_in_the_mouth low-spirited', 'abdomen venter stomach belly abdominal_cavity', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'during', 'sex sexual_activity sexual_practice sex_activity sexual_urge gender sexuality arouse excite turn_on wind_up', 'vaginal', 'bleeding hemorrhage haemorrhage shed_blood bleed leech phlebotomize phlebotomise run', "between betwixt 'tween", 'periods time_period period_of_time period geological_period menstruation menses menstruum catamenia flow point full_stop stop full_point', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'after subsequently later afterwards afterward later_on', 'intercourse social_intercourse sexual_intercourse sex_act copulation coitus coition sexual_congress congress sexual_relation relation carnal_knowledge', 'discharge venting emission expelling spark arc electric_arc electric_discharge outpouring run dismissal dismission firing liberation release sack sacking waiver firing_off dispatch complete free fire go_off acquit assoil clear exonerate exculpate exhaust expel eject drop drop_off set_down put_down unload muster_out empty', 'from', 'penis phallus member', 'burning combustion burn electrocution burning_at_the_stake fire burn_down glow combust bite sting incinerate cauterize cauterise sunburn cut burn_off burn_up', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'itching itch itchiness rub scratch spoil', 'at astatine At atomic_number_85', 'the', 'opening gap opening_night curtain_raising possibility possible_action orifice porta hatchway scuttle chess_opening first_step initiative opening_move open open_up unfold spread spread_out afford give', 'of', 'the', 'penis phallus member', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'swelling puffiness lump bulge bump hump gibbosity gibbousness jut prominence protuberance protrusion extrusion excrescence intumescence intumescency swell puff_up swell_up intumesce tumefy tumesce well_up well', 'in inch indium In atomic_number_49 Indiana Hoosier_State IN inwards inward', 'the', 'testicles testis testicle orchis ball ballock bollock nut egg']
# CLEAN SYNONYMS:  ['vaginal', 'discharge venting emission expelling spark arc electricarc electricdischarge outpouring run dismissal dismission firing liberation release sack sacking waiver firingoff dispatch complete free fire gooff acquit assoil clear exonerate exculpate exhaust expel eject drop dropoff setdown putdown unload musterout empty', 'burning combustion burn electrocution burningatthestake fire burndown glow combust bite sting incinerate cauterize cauterise sunburn cut burnoff burnup', 'sensation esthesis aesthesis senseexperience senseimpression sensedatum ace adept champion maven mavin virtuoso genius hotshot star superstar whiz whizz wizard wiz sense sentience sentiency sensoryfaculty', 'during', 'urinating urinate make piddle puddle micturate piss pee peepee makewater relieveoneself takealeak spendapenny wee weewee passwater', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'in inch indium In Indiana HoosierState IN inwards inward', 'the', 'lower lowerberth takedown letdown getdown bringdown lour turndown depress frown glower low lowtoned lowpitched abject lowdown miserable scummy scurvy humble lowly modest small depleted broken crushed humbled humiliated gloomy grim blue depressed dispirited down downcast downhearted downinthemouth lowspirited', 'abdomen venter stomach belly abdominalcavity', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'during', 'sex sexualactivity sexualpractice sexactivity sexualurge gender sexuality arouse excite turnon windup', 'vaginal', 'bleeding hemorrhage haemorrhage shedblood bleed leech phlebotomize phlebotomise run', 'between betwixt tween', 'periods timeperiod periodoftime period geologicalperiod menstruation menses menstruum catamenia flow point fullstop stop fullpoint', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'after subsequently later afterwards afterward lateron', 'intercourse socialintercourse sexualintercourse sexact copulation coitus coition sexualcongress congress sexualrelation relation carnalknowledge', 'discharge venting emission expelling spark arc electricarc electricdischarge outpouring run dismissal dismission firing liberation release sack sacking waiver firingoff dispatch complete free fire gooff acquit assoil clear exonerate exculpate exhaust expel eject drop dropoff setdown putdown unload musterout empty', 'from', 'penis phallus member', 'burning combustion burn electrocution burningatthestake fire burndown glow combust bite sting incinerate cauterize cauterise sunburn cut burnoff burnup', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'itching itch itchiness rub scratch spoil', 'at astatine At', 'the', 'opening gap openingnight curtainraising possibility possibleaction orifice porta hatchway scuttle chessopening firststep initiative openingmove open openup unfold spread spreadout afford give', 'of', 'the', 'penis phallus member', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'swelling puffiness lump bulge bump hump gibbosity gibbousness jut prominence protuberance protrusion extrusion excrescence intumescence intumescency swell puffup swellup intumesce tumefy tumesce wellup well', 'in inch indium In Indiana HoosierState IN inwards inward', 'the', 'testicles testis testicle orchis ball ballock bollock nut egg']
# WORD_LIST: ['high fever', 'cough', 'muscle aches', 'headache', 'chills', 'loss of appetite', 'chills', 'fatigue', 'sore throat', ' runny or stuffy nose', ' stomach ache', 'diarrhea', 'vomiting']
# WORD_LIST_NEW: ['high fever', 'cough', 'muscle aches', 'headache', 'chills', 'loss of appetite', 'chills', 'fatigue', 'sore throat', 'runny or stuffy nose', 'stomach ache', 'diarrhea', 'vomiting']
# joined_symps: high fever cough muscle aches headache chills loss of appetite chills fatigue sore throat runny or stuffy nose stomach ache diarrhea vomiting
# SYNONYMS: ['high heights senior_high_school senior_high highschool high_school high_gear eminent high-pitched in_high_spirits gamey gamy mellow high_up richly luxuriously', 'fever febrility febricity pyrexia feverishness', 'cough coughing', 'muscle musculus muscular_tissue muscleman brawn brawniness muscularity sinew heftiness', 'aches ache aching hurt suffer yearn yen pine languish smart', 'headache concern worry vexation head_ache cephalalgia', 'chills chill iciness gelidity frisson shiver quiver shudder thrill tingle shivering pall cool cool_down', 'loss deprivation red_ink red personnel_casualty passing departure exit expiration going release', 'of', 'appetite appetency appetence', 'chills chill iciness gelidity frisson shiver quiver shudder thrill tingle shivering pall cool cool_down', 'fatigue weariness tiredness fatigue_duty tire pall weary jade wear_upon tire_out wear wear_out outwear wear_down fag_out fag', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'runny fluid', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'stuffy airless close unaired stodgy', 'nose olfactory_organ nozzle intrude horn_in pry poke scent wind nuzzle', 'stomach tummy tum breadbasket abdomen venter belly digest endure stick_out bear stand tolerate support brook abide suffer put_up', 'ache aching hurt suffer yearn yen pine languish smart', 'diarrhea diarrhoea looseness_of_the_bowels looseness', 'vomiting vomit emesis regurgitation disgorgement puking vomit_up purge cast sick cat be_sick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throw_up']
# CLEAN SYNONYMS:  ['high heights seniorhighschool seniorhigh highschool highschool highgear eminent highpitched inhighspirits gamey gamy mellow highup richly luxuriously', 'fever febrility febricity pyrexia feverishness', 'cough coughing', 'muscle musculus musculartissue muscleman brawn brawniness muscularity sinew heftiness', 'aches ache aching hurt suffer yearn yen pine languish smart', 'headache concern worry vexation headache cephalalgia', 'chills chill iciness gelidity frisson shiver quiver shudder thrill tingle shivering pall cool cooldown', 'loss deprivation redink red personnelcasualty passing departure exit expiration going release', 'of', 'appetite appetency appetence', 'chills chill iciness gelidity frisson shiver quiver shudder thrill tingle shivering pall cool cooldown', 'fatigue weariness tiredness fatigueduty tire pall weary jade wearupon tireout wear wearout outwear weardown fagout fag', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'runny fluid', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'stuffy airless close unaired stodgy', 'nose olfactoryorgan nozzle intrude hornin pry poke scent wind nuzzle', 'stomach tummy tum breadbasket abdomen venter belly digest endure stickout bear stand tolerate support brook abide suffer putup', 'ache aching hurt suffer yearn yen pine languish smart', 'diarrhea diarrhoea loosenessofthebowels looseness', 'vomiting vomit emesis regurgitation disgorgement puking vomitup purge cast sick cat besick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throwup']
# WORD_LIST: ['sores on the penis', 'sores near the vagina', 'tender lumps in the groin']
# WORD_LIST_NEW: ['sores on the penis', 'sores near the vagina', 'tender lumps in the groin']
# joined_symps: sores on the penis sores near the vagina tender lumps in the groin
# SYNONYMS: ['sores sore', 'on along', 'the', 'penis phallus member', 'sores sore', 'near approach come_on go_up draw_near draw_close come_near close nigh cheeseparing penny-pinching skinny dear good approximate about almost most nearly virtually well-nigh', 'the', 'vagina', "tender legal_tender stamp attendant attender bid ship's_boat pinnace cutter supply_ship offer tenderize tenderise sensitive sore raw affectionate fond lovesome warm untoughened crank cranky tippy", 'lumps ball clod glob lump clump chunk swelling puffiness lout stumblebum goon oaf lubber lummox gawk hunk collocate', 'in inch indium In atomic_number_49 Indiana Hoosier_State IN inwards inward', 'the', 'groin inguen breakwater groyne mole bulwark seawall jetty']
# CLEAN SYNONYMS:  ['sores sore', 'on along', 'the', 'penis phallus member', 'sores sore', 'near approach comeon goup drawnear drawclose comenear close nigh cheeseparing pennypinching skinny dear good approximate about almost most nearly virtually wellnigh', 'the', 'vagina', 'tender legaltender stamp attendant attender bid shipsboat pinnace cutter supplyship offer tenderize tenderise sensitive sore raw affectionate fond lovesome warm untoughened crank cranky tippy', 'lumps ball clod glob lump clump chunk swelling puffiness lout stumblebum goon oaf lubber lummox gawk hunk collocate', 'in inch indium In Indiana HoosierState IN inwards inward', 'the', 'groin inguen breakwater groyne mole bulwark seawall jetty']
# WORD_LIST: ['Fever', 'Fatigue', 'Loss of appetite', 'Nausea', 'Vomiting', 'Abdominal pain', 'Dark urine', 'Clay-colored bowel movement', 'joint pain', 'Jaundice']
# WORD_LIST_NEW: ['fever', 'fatigue', 'loss of appetite', 'nausea', 'vomiting', 'abdominal pain', 'dark urine', 'claycolored bowel movement', 'joint pain', 'jaundice']
# joined_symps: fever fatigue loss of appetite nausea vomiting abdominal pain dark urine claycolored bowel movement joint pain jaundice
# SYNONYMS: ['fever febrility febricity pyrexia feverishness', 'fatigue weariness tiredness fatigue_duty tire pall weary jade wear_upon tire_out wear wear_out outwear wear_down fag_out fag', 'loss deprivation red_ink red personnel_casualty passing departure exit expiration going release', 'of', 'appetite appetency appetence', 'nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomit_up purge cast sick cat be_sick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throw_up', 'abdominal abdominal_muscle ab', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'dark darkness iniquity wickedness shadow night nighttime black sinister dour glowering glum moody morose saturnine sour sullen benighted obscure blue dingy disconsolate dismal gloomy grim sorry drab drear dreary colored coloured dark-skinned non-white', 'urine piss pee piddle weewee water', 'claycolored', 'bowel intestine gut', 'movement motion move motility social_movement front campaign cause crusade drive effort apparent_motion apparent_movement bowel_movement bm drift trend', 'joint articulation articulatio join juncture junction roast marijuana_cigarette reefer stick spliff articulate', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'jaundice icterus bitterness acrimony acerbity tartness thorniness']
# CLEAN SYNONYMS:  ['fever febrility febricity pyrexia feverishness', 'fatigue weariness tiredness fatigueduty tire pall weary jade wearupon tireout wear wearout outwear weardown fagout fag', 'loss deprivation redink red personnelcasualty passing departure exit expiration going release', 'of', 'appetite appetency appetence', 'nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomitup purge cast sick cat besick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throwup', 'abdominal abdominalmuscle ab', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'dark darkness iniquity wickedness shadow night nighttime black sinister dour glowering glum moody morose saturnine sour sullen benighted obscure blue dingy disconsolate dismal gloomy grim sorry drab drear dreary colored coloured darkskinned nonwhite', 'urine piss pee piddle weewee water', 'claycolored', 'bowel intestine gut', 'movement motion move motility socialmovement front campaign cause crusade drive effort apparentmotion apparentmovement bowelmovement bm drift trend', 'joint articulation articulatio join juncture junction roast marijuanacigarette reefer stick spliff articulate', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'jaundice icterus bitterness acrimony acerbity tartness thorniness']
# WORD_LIST: ['high fever', 'cough', 'aching muscles', 'sore throat', 'stomach pain', 'chest pain', 'diarrhea', 'difficulty breathing', 'pneumonia', 'acute respiratory distress syndrome']
# WORD_LIST_NEW: ['high fever', 'cough', 'aching muscles', 'sore throat', 'stomach pain', 'chest pain', 'diarrhea', 'difficulty breathing', 'pneumonia', 'acute respiratory distress syndrome']
# joined_symps: high fever cough aching muscles sore throat stomach pain chest pain diarrhea difficulty breathing pneumonia acute respiratory distress syndrome
# SYNONYMS: ['high heights senior_high_school senior_high highschool high_school high_gear eminent high-pitched in_high_spirits gamey gamy mellow high_up richly luxuriously', 'fever febrility febricity pyrexia feverishness', 'cough coughing', 'aching ache hurt suffer yearn yen pine languish smart achy', 'muscles muscle musculus muscular_tissue muscleman brawn brawniness muscularity sinew heftiness', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'stomach tummy tum breadbasket abdomen venter belly digest endure stick_out bear stand tolerate support brook abide suffer put_up', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'chest thorax pectus breast chest_of_drawers bureau dresser', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt', 'diarrhea diarrhoea looseness_of_the_bowels looseness', 'difficulty trouble difficultness', "breathing external_respiration respiration ventilation breathe take_a_breath respire suspire rest catch_one's_breath take_a_breather emit pass_off eupneic eupnoeic", 'pneumonia', 'acute acute_accent ague intense discriminating incisive keen knifelike penetrating penetrative piercing sharp acuate needlelike', 'respiratory', 'distress hurt suffering distraint straiten', 'syndrome']
# CLEAN SYNONYMS:  ['high heights seniorhighschool seniorhigh highschool highschool highgear eminent highpitched inhighspirits gamey gamy mellow highup richly luxuriously', 'fever febrility febricity pyrexia feverishness', 'cough coughing', 'aching ache hurt suffer yearn yen pine languish smart achy', 'muscles muscle musculus musculartissue muscleman brawn brawniness muscularity sinew heftiness', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'stomach tummy tum breadbasket abdomen venter belly digest endure stickout bear stand tolerate support brook abide suffer putup', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'chest thorax pectus breast chestofdrawers bureau dresser', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt', 'diarrhea diarrhoea loosenessofthebowels looseness', 'difficulty trouble difficultness', 'breathing externalrespiration respiration ventilation breathe takeabreath respire suspire rest catchonesbreath takeabreather emit passoff eupneic eupnoeic', 'pneumonia', 'acute acuteaccent ague intense discriminating incisive keen knifelike penetrating penetrative piercing sharp acuate needlelike', 'respiratory', 'distress hurt suffering distraint straiten', 'syndrome']
# WORD_LIST: ['Fever', 'cough', 'sore throat', 'runny nose', 'stuffy nose', 'watery eyes', 'red eyes', 'body aches', 'headache', 'fatigue', 'diarrhea', 'nausea', 'vomiting']
# WORD_LIST_NEW: ['fever', 'cough', 'sore throat', 'runny nose', 'stuffy nose', 'watery eyes', 'red eyes', 'body aches', 'headache', 'fatigue', 'diarrhea', 'nausea', 'vomiting']
# joined_symps: fever cough sore throat runny nose stuffy nose watery eyes red eyes body aches headache fatigue diarrhea nausea vomiting
# SYNONYMS: ['fever febrility febricity pyrexia feverishness', 'cough coughing', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'runny fluid', 'nose olfactory_organ nozzle intrude horn_in pry poke scent wind nuzzle', 'stuffy airless close unaired stodgy', 'nose olfactory_organ nozzle intrude horn_in pry poke scent wind nuzzle', 'watery reeking washy weak', 'eyes eye oculus optic center centre middle heart eyeball', 'red redness Red Red_River Bolshevik Marxist bolshie bolshy loss red_ink reddish ruddy blood-red carmine cerise cherry cherry-red crimson ruby ruby-red scarlet violent reddened red-faced flushed', 'eyes eye oculus optic center centre middle heart eyeball', 'body organic_structure physical_structure dead_body torso trunk consistency consistence eubstance soundbox personify', 'aches ache aching hurt suffer yearn yen pine languish smart', 'headache concern worry vexation head_ache cephalalgia', 'fatigue weariness tiredness fatigue_duty tire pall weary jade wear_upon tire_out wear wear_out outwear wear_down fag_out fag', 'diarrhea diarrhoea looseness_of_the_bowels looseness', 'nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomit_up purge cast sick cat be_sick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throw_up']
# CLEAN SYNONYMS:  ['fever febrility febricity pyrexia feverishness', 'cough coughing', 'sore sensitive raw tender afflictive painful huffy mad', 'throat pharynx', 'runny fluid', 'nose olfactoryorgan nozzle intrude hornin pry poke scent wind nuzzle', 'stuffy airless close unaired stodgy', 'nose olfactoryorgan nozzle intrude hornin pry poke scent wind nuzzle', 'watery reeking washy weak', 'eyes eye oculus optic center centre middle heart eyeball', 'red redness Red RedRiver Bolshevik Marxist bolshie bolshy loss redink reddish ruddy bloodred carmine cerise cherry cherryred crimson ruby rubyred scarlet violent reddened redfaced flushed', 'eyes eye oculus optic center centre middle heart eyeball', 'body organicstructure physicalstructure deadbody torso trunk consistency consistence eubstance soundbox personify', 'aches ache aching hurt suffer yearn yen pine languish smart', 'headache concern worry vexation headache cephalalgia', 'fatigue weariness tiredness fatigueduty tire pall weary jade wearupon tireout wear wearout outwear weardown fagout fag', 'diarrhea diarrhoea loosenessofthebowels looseness', 'nausea sickness', 'vomiting vomit emesis regurgitation disgorgement puking vomitup purge cast sick cat besick disgorge regorge retch puke barf spew spue chuck upchuck honk regurgitate throwup']
# WORD_LIST: ['Localized inflammation of the skin', 'redness', 'heat', 'swelling', 'pain']
# WORD_LIST_NEW: ['localized inflammation of the skin', 'redness', 'heat', 'swelling', 'pain']
# joined_symps: localized inflammation of the skin redness heat swelling pain
# SYNONYMS: ['localized place localize localise focalize focalise set localised', 'inflammation redness rubor excitement excitation fervor fervour inflaming ignition firing lighting kindling', 'of', 'the', 'skin tegument cutis hide pelt peel clamber scramble shin shinny struggle sputter scrape bark pare', 'redness inflammation rubor red', 'heat heat_energy hotness high_temperature warmth passion estrus oestrus rut heating_system heating_plant heating heat_up inflame stir_up wake ignite fire_up hot_up', 'swelling puffiness lump bulge bump hump gibbosity gibbousness jut prominence protuberance protrusion extrusion excrescence intumescence intumescency swell puff_up swell_up intumesce tumefy tumesce well_up well', 'pain hurting painfulness pain_sensation painful_sensation pain_in_the_neck nuisance annoyance bother botheration infliction pain_in_the_ass trouble ail anguish hurt']
# CLEAN SYNONYMS:  ['localized place localize localise focalize focalise set localised', 'inflammation redness rubor excitement excitation fervor fervour inflaming ignition firing lighting kindling', 'of', 'the', 'skin tegument cutis hide pelt peel clamber scramble shin shinny struggle sputter scrape bark pare', 'redness inflammation rubor red', 'heat heatenergy hotness hightemperature warmth passion estrus oestrus rut heatingsystem heatingplant heating heatup inflame stirup wake ignite fireup hotup', 'swelling puffiness lump bulge bump hump gibbosity gibbousness jut prominence protuberance protrusion extrusion excrescence intumescence intumescency swell puffup swellup intumesce tumefy tumesce wellup well', 'pain hurting painfulness painsensation painfulsensation painintheneck nuisance annoyance bother botheration infliction painintheass trouble ail anguish hurt']
# WORD_LIST: ['fever', 'headache', 'body aches', 'mild rash', 'swollen lymph glands', 'rapid onset of severe headache', 'high fever', 'stiff neck', 'nausea or vomiting', 'difficulty swallowing', 'drowsiness', 'confusion', 'loss of consciousness', 'lack of coordination', 'muscle weakness', 'paralysis']
# WORD_LIST_NEW: ['fever', 'headache', 'body aches', 'mild rash', 'swollen lymph glands', 'rapid onset of severe headache', 'high fever', 'stiff neck', 'nausea or vomiting', 'difficulty swallowing', 'drowsiness', 'confusion', 'loss of consciousness', 'lack of coordination', 'muscle weakness', 'paralysis']
# joined_symps: fever headache body aches mild rash swollen lymph glands rapid onset of severe headache high fever stiff neck nausea or vomiting difficulty swallowing drowsiness confusion loss of consciousness lack of coordination muscle weakness paralysis
# ...
# WORD_LIST: ['frequent urges to urinate', 'difficulty commencing and maintaining urination', 'blood in the urine', 'painful urination and ejaculation', 'difficulty achieving or maintaining an erection']
# WORD_LIST_NEW: ['frequent urges to urinate', 'difficulty commencing and maintaining urination', 'blood in the urine', 'painful urination and ejaculation', 'difficulty achieving or maintaining an erection']
# joined_symps: frequent urges to urinate difficulty commencing and maintaining urination blood in the urine painful urination and ejaculation difficulty achieving or maintaining an erection
# SYNONYMS: ['frequent patronize patronise shop shop_at buy_at sponsor haunt', 'urges urge impulse itch urge_on press exhort recommend advocate cheer root_on inspire barrack pep_up', 'to', 'urinate make piddle puddle micturate piss pee pee-pee make_water relieve_oneself take_a_leak spend_a_penny wee wee-wee pass_water', 'difficulty trouble difficultness', 'commencing get_down begin get start_out start set_about set_out commence lead_off start_up embark_on', 'and', 'maintaining keep maintain hold conserve preserve keep_up sustain assert asseverate wield exert defend uphold observe', 'urination micturition', 'blood rake rakehell profligate rip roue lineage line line_of_descent descent bloodline blood_line pedigree ancestry origin parentage stemma stock', 'in inch indium In atomic_number_49 Indiana Hoosier_State IN inwards inward', 'the', 'urine piss pee piddle weewee water', 'painful afflictive sore atrocious abominable awful dreadful terrible unspeakable irritating', 'urination micturition', 'and', 'ejaculation interjection', 'difficulty trouble difficultness', 'achieving achieve accomplish attain reach', 'or Oregon Beaver_State OR operating_room operating_theater operating_theatre surgery', 'maintaining keep maintain hold conserve preserve keep_up sustain assert asseverate wield exert defend uphold observe', 'an Associate_in_Nursing AN', 'erection hard-on erecting']
# CLEAN SYNONYMS:  ['frequent patronize patronise shop shopat buyat sponsor haunt', 'urges urge impulse itch urgeon press exhort recommend advocate cheer rooton inspire barrack pepup', 'to', 'urinate make piddle puddle micturate piss pee peepee makewater relieveoneself takealeak spendapenny wee weewee passwater', 'difficulty trouble difficultness', 'commencing getdown begin get startout start setabout setout commence leadoff startup embarkon', 'and', 'maintaining keep maintain hold conserve preserve keepup sustain assert asseverate wield exert defend uphold observe', 'urination micturition', 'blood rake rakehell profligate rip roue lineage line lineofdescent descent bloodline bloodline pedigree ancestry origin parentage stemma stock', 'in inch indium In Indiana HoosierState IN inwards inward', 'the', 'urine piss pee piddle weewee water', 'painful afflictive sore atrocious abominable awful dreadful terrible unspeakable irritating', 'urination micturition', 'and', 'ejaculation interjection', 'difficulty trouble difficultness', 'achieving achieve accomplish attain reach', 'or Oregon BeaverState OR operatingroom operatingtheater operatingtheatre surgery', 'maintaining keep maintain hold conserve preserve keepup sustain assert asseverate wield exert defend uphold observe', 'an AssociateinNursing AN', 'erection hardon erecting']
# 28 documents [(['fluid runny', 'beaverst operatingroom operatingth or oregon surgery', 'airless clos stodgy stuffy unair', 'hornin intrud nos nozzl nuzzl olfactoryorg pok pry scent wind', 'afflict huffy mad pain raw sensit sor tend', 'pharynx throat', 'cough', 'congest overcrowd', 'body consist deadbody eubst organicstruct person physicalstruct soundbox torso trunk', 'ach hurt lanct pin smart suff yearn yen', 'sneez sternut'], 'Common Cold'), (['cent ey eyebal heart middl ocul opt', 'aggrav annoy both discomfort excit innerv irrit piqu provoc temp vex', 'runny', 'operatingroom or surgery', 'clos stuffy', 'intrud nozzl olfactoryorg pry wind', 'bouff gusty intumesc puffy tumesc tumid turgid', 'reek washy watery weak', 'ey heart ocul', 'sternut', 'ablaz conflagr enkindl fireup heat ignit inflam kindl red stirup wak', 'antsy fidg fret itchy', 'intrud nozzl olfactoryorg pry wind', 'and', 'throat'], 'Allergies'), (['red rub', 'of', 'ey heart ocul', 'fidg itchy', 'ey heart ocul', 'buck bust charg deplum displum fierc lachrym lacrim pluck pul rupt shoot shootdown snap tear triggerhappy veh viol wat', 'operatingroom or surgery', 'bit burn burndown burningatthestak burnoff burnup caut combust cut electrocut fir glow incin sting sunburn', 'ac adept aesthes champ esthes geni hotshot mav mavin sens sensedat senseexpery senseimpress sensoryfacul senty star superst virtuoso whiz whizz wiz wizard', '', 'eyebal orb'], 'Conjunctivitis'), (['washy weak', 'atlarg easy escap fre idl inform lax letloos lib light loos ontheloos op promiscu relax releas slack slut unaffix unleash unloos wanton', 'bm cac can commod crap defec deject faec faecalmat fec fecalmat mak ord pot potty shit stool takeacrap takeashit throne til toilet', 'buy frequ haunt patron shop spons', 'bowel gut intestin', 'apparentmot apparentmov bowelmov campaign caus crusad drift driv effort front mot motil mov socialmov trend', 'bellyach gastralg stomachach', 'nause sick', 'allfir bal blink bloody bloom crash damn flam fuck', 'cac commod defec faec fec mak pot shit takeacrap throne toilet'], 'Irritable Bowel Syndrome (IBS)'), (['acut intens vivid', 'ail anct both inflict nuis painfulsens painintheass painintheneck painsens troubl', 'from', 'onesid', 'andso andth so then', 'banquet bedcov bedspread broadcast cattlefarm cattleranch circ circul counterp diffus dispers dissemin distribut facingp fanout feast gap goaround overspread passaround past prop ranch scat spread spreadhead spreading spreadout spreads unfold', 'agreatd much oft oftentim ofttim', 'dur end go holdout holdup last liv liveon longl longlast perm persist surv', 'a adenin amp angstrom angstromunit antiophthalmicfact axerophthol deoxyadenosinemonophosph group type vitamin', 'few', 'hour hr minut timeofday', 'accompany attachto attend comewi comp company follow gowi keepcompany playalong', 'asid away by', 'sick'], 'Acute Headache '), (['ceaseless changeless const constantqu incess inv invary neverend perpet unceas unremit unv', 'benumb blunt bor damp dead dens dim dul dumb hoh irksom lead muffl mut numb obtus pal slow slug soft tedy thud tiresom tonedown wearisom', 'anct both inflict pain painfulsens painintheneck troubl', '', 'brain capitul caput channel chief direct drumhead forefront foreland fountainhead guid head headland headspr headteach headup headway headword maneuv manoeuv manoeuvr mind nou oralsex pass point princip promont psych quest readwritehead schoolprincipal ste straits topdog', 'ars ass backsid bathroom behind bottom bum bun but buttock canbuoy crap derry dismiss displac fanny forceout funda givenot givetheax givethesack hindend hindquart john keist lav nat postery potty prat privy putup rear rearend rump sack seat sendaway stern tail tailend termin tin tint tooshy tush', 'cobblerslast conclud dea fin finalst holdout inconclud lastplac liveon lowest net shoemakerslast stoppingpoint termin utmost', '', 'half onehalf', 'an associateinnurs', 'hr timeofday', 'to', 'respect sev vary', 'clarenceday clarenceshep ...
# 28 classes ['Acute Headache ', 'Allergies', 'Alzheimer', 'Avian Influenza', 'Breast Cancer', 'Chickenpox', 'Chlamydia', 'Chronic Headache ', 'Common Cold', 'Conjunctivitis', 'Coronary Heart Disease', "Crohn's Disease", 'Dermatitis', 'E Coli Infection', 'Eating Disorders including Anorexia & Bulimia Nervosa', 'HBV;Liver infection', 'Hepatitis B', 'Influenza', 'Intestinal Gas', 'Irritable Bowel Syndrome (IBS)', 'Nausea and Vomiting', 'Pregrancy', 'Prostate Cancer', 'Sleep Apnea', 'Stroke', 'Swine Influenza', 'West Nile Virus', 'Zika Virus']
# 333 unique stemmed words ['a adenin amp angstrom angstromunit antiophthalmicfact axerophthol deoxyadenosinemonophosph group type vitamin', 'ab abdomin abdominalmusc', 'abbrevy abridg boildown comedown contract cutback cutdown decoct deoxid dilut foreshort keepdown meltoff quash repress rockbottom scaledown shrink slim slimdown subdu subjug thinout trim trimback trimdown', 'abdom abid bear bel breadbasket brook digest putup stand stickout stomach support tol tum tummy vent', 'abdomin', 'abdominalcav stomach', 'abid bel brook end stand stomach support tum vent', 'abject blu bringdown brok crush deplet depress dispirit down downcast downheart downinthemou frown gloom grim humbl humy letdown lour low lowdown lowerber lowpitch lowspirit lowton mis scummy scurvy smal takedown turndown', 'ablaz conflagr enkindl fireup heat ignit inflam kindl red stirup wak', 'abomin atrocy dread pain terr unspeak', 'about almost approach approxim cheesep comenear comeon dear drawclos drawnear good goup most near nigh pennypinch skinny virt wellnigh', 'abrupt brusqu curt gruff short trunt', 'abs escap leaveout miss neglect omit overleap overlook pretermit', 'ac adept aesthes champ esthes geni hotshot mav mavin sens sensedat senseexpery senseimpress sensoryfacul senty star superst virtuoso whiz whizz wiz wizard', 'acceiv bury eatup getdown immers livewi swallow swallowup takeback unsay withdraw', 'accel acceleratorp blow blust boast brag flat gas gasconad gaseousst gasol gasolin gasp gun naturalga petrol shootalin swash throttle tout vaunt', 'acceleratorp blust brag gas gaseousst gasolin gun petrol swash tout', 'accompany attachto attend comewi comp company follow gowi keepcompany playalong', 'accompl achiev attain reach', 'account describ report', 'acerb acrimony icter jaund tart thorny', 'ach hurt lanct pin smart suff yearn yen', 'achy lanct smart yearn', 'acquit arc assoil clear complet discharg dismit dispatch drop dropoff eject electricarc electricdischarg emit empty exculp exhaust exon expel firingoff gooff musterout outpo putdown run setdown spark unload waiv', 'act bodilyfunct bodilyprocess bodyprocess naturalact naturalprocess', 'acu acuteacc agu discrimin incid keen knifelik needlelik penet pierc sharp', 'acut intens vivid', 'address oralpres publicspeak speechmak speechproduc ut', 'adenin angstrom antiophthalmicfact deoxyadenosinemonophosph type', 'adept champ geni mav sens senseexpery sensoryfacul star virtuoso whizz wizard', 'adiposetissu avoirdupo blub fat fattenout fattenup fatty fattytissu fertil fleshout juicy plump plumpout produc', 'advoc barrack che exhort impuls inspir pepup press recommend rooton urg urgeon', 'aer air airout airtravel airwav atmosph aur avy bar beam breez gentlewind lin melodiclin melodicphras melody publ send strain transmit tun ventil zephyr', 'affair mat thing', 'affect bid crank cranky fond legaltend lovesom off pinnac sensit shipsbo stamp supply tippy untough warm', 'afflict huffy mad pain raw sensit sor tend', 'afford chessop curtainra firststep giv hatchway op openingmov openingnight openup port poss possibleact scuttl spreadout', 'aft afterward lat lateron subsequ', 'aggrav annoy both discomfort excit innerv irrit piqu provoc temp vex', 'agr apprehend empath inf intellect interpret read real reason savvy see sympath sympathy transl understand', 'agreatd much oft oftentim ofttim', 'ail anct both inflict nuis painfulsens painintheass painintheneck painsens troubl', 'aim billet blankspac comein comeout commit grad hom ident invest lay lieu off piazz plaz pos post property put rank seat set sho sit spac stat stead target', 'airless clos stodgy stuffy unair', 'allfir bal blink bloody bloom crash damn flam fuck', 'almost approxim clos comenear dear drawnear goup near pennypinch virt', 'along on', 'aloud brassy cheap flash flashy gar gaudy gimcrack loud meretricy tacky tatty tawdry trashy', 'alt chang commut convert deep exchang interchang mod shift switch transf', 'an associateinnurs', 'anatom bod build chass co ...
# classes_details [{'treatments': 'Stay hydrated;rest;sooth a sore throat using saltwater gargle;take over the counter cold and cough medications\n', 'danger level': '1', 'synonyms': 'Upper Respiratory Tract;Nose and Throat Infection', 'class': 'Common Cold'}, {'treatments': 'Remove the cause of allergy; \notherwise take Antihistamines to relieve sneezing;Decongestants to relieve congestions in nasal membranes;Anti inflamary agents to reduce;Allergy shots', 'danger level': '1', 'synonyms': 'Allergic Reaction', 'class': 'Allergies'}, {'treatments': 'See a doctor;Bacterial cases can be treated with antibiotic eye drops;Allergic reactions can be treated with other eye drops', 'danger level': '1', 'synonyms': 'Pink Eye', 'class': 'Conjunctivitis'}, {'treatments': 'Diarrhea will typically go away in 2 days;Consult a physician if you experience severe stomach or rectum pain, fever, or diarrhea lasting longer than 3 days', 'danger level': '1', 'synonyms': 'Diarrhea', 'class': 'Irritable Bowel Syndrome (IBS)'}, {'treatments': 'Sleep and rest;Icepack over eyes or head;Moderate use of OTC medicines such as acetaminophen, aspirin, or ibuprofen may relieve pain', 'danger level': '1', 'synonyms': 'migraine;Headache ', 'class': 'Acute Headache '}, {'treatments': 'Sleep and rest;icepack over eyes or head;Note: overuse of pain relieving medicines may result in "analgesic rebound headaches"', 'danger level': '1', 'synonyms': 'Tension type;Headache ', 'class': 'Chronic Headache '}, {'treatments': 'Take digestive enzyme supplements, such as Beano and lactase supplements;Eat several small meals throughout the day instead of two or three large ones;Take a stroll after each meal', 'danger level': '1', 'synonyms': 'Stomach Ache', 'class': 'Intestinal Gas'}, {'treatments': 'Most cases resolve within a couple days without treatments;Avoid food and water that may be contaminated;Wash your hands thoroughly and frequently;Avoid sharing eating utencils', 'danger level': '1', 'synonyms': 'Labrynthitis;Stomach ulcers;Hepatitis;Meningitis', 'class': 'Nausea and Vomiting'}, {'treatments': 'Visit a hospital immediately', 'danger level': '1', 'synonyms': '', 'class': 'E Coli Infection'}, {'treatments': 'See a professional doctor;Use Azithromycin or Doxycycline', 'danger level': '4', 'synonyms': 'Sexually Transmitted Infection (STI)', 'class': 'Chlamydia'}, {'treatments': 'Mild flu treated with rest and fluids; See a doctor in the case of severe flu', 'danger level': '1', 'synonyms': 'Flu', 'class': 'Influenza'}, {'treatments': 'See a doctor immediately;Take antiviral drugs', 'danger level': '6', 'synonyms': 'Herpes', 'class': 'Hepatitis B'}, {'treatments': 'See a doctor immediately;Take antiviral drugs for chronic HBV;No medication is availiable for acute infection', 'danger level': '5', 'synonyms': '', 'class': 'HBV;Liver infection'}, {'treatments': 'Seek help from a professional healthcare provider immediately', 'danger level': '9', 'synonyms': 'H5N1', 'class': 'Avian Influenza'}, {'treatments': 'Recommended medicines for swine influenza are oseltamivir, peramivir, and zanamivir', 'danger level': '8', 'synonyms': 'H1N1', 'class': 'Swine Influenza'}, {'treatments': 'Compress;corticosteroid cream;calcineurin inhibitors;See a doctor for further assistance', 'danger level': '1', 'synonyms': '', 'class': 'Dermatitis'}, {'treatments': 'Please see a healthcare professional;There are no specific treatments for West Nile Virus in humans', 'danger level': '8', 'synonyms': '', 'class': 'West Nile Virus'}, {'treatments': 'Get plenty of rest;drink fluid;take medicine such as acetaminophen;Consult with a professional doctor', 'danger level': '4', 'synonyms': '', 'class': 'Zika Virus'}, {'treatments': 'Drink plenty of fluid;Take Tylenol;Consult with a doctor', 'danger level': '2', 'synonyms': 'Varicella Zoster Virus', 'class': 'Chickenpox'}, {'treatments': 'Cholinesterase inhibitors;Memantine(Namenda);Please consult with a professional doctor', 'danger level': '4', 'synonyms' ...

# %%
# create our training data
training = []
output = []
# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    print("TOKENIZED WORDS: ",pattern_words)
    # stem each word
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    # create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# TOKENIZED WORDS:  ['bowel diarrhe diarrhoe loos of the', 'cramp halt hamp iron musc spasm strangle', 'abdomin pain']
# TOKENIZED WORDS:  ['eyelid lid palpebr', 'epiphor epistroph', 'conjunctivit pinkey']
# TOKENIZED WORDS:  ['head tilt', 'incoordin', 'atax ataxy dyssynerg mot', 'trem', 'pares']
# TOKENIZED WORDS:  ['pap', 'nod tuberc']
# TOKENIZED WORDS:  ['defect judg', 'ach cephalalg concern headach vex worry', 'detery mem', 'down duty fag fatigu jad out outwear pal tir upon wear weary', 'difficul difficult troubl', 'insomn']
# TOKENIZED WORDS:  ['barf be cast cat chuck disgorg emes honk puk purg regorg regurgit retch sick spew spu throw up upchuck vomit', 'ment stat', 'papilledem']
# TOKENIZED WORDS:  ['acquit arc assoil clear complet discharg dismiss dismit dispatch drop eject elect emit empty exculp exhaust exon expel fir fre go lib must off outpo put releas run sack set spark unload vent waiv', 'memb pen phall', 'scrotal swel', 'ancestry blood bloodlin desc lin origin par pedigr proflig rak rakehel rip rou stemm stock']
# TOKENIZED WORDS:  ['brass plaqu tablet', 'noninflam perifollicul pust superf', 'inflam ker']
# TOKENIZED WORDS:  ['light touch', 'predisposit sens sensit', 'weak', 'sev']
# TOKENIZED WORDS:  ['cephalalg head headach worry', 'febr febril fev pyrex']
# TOKENIZED WORDS:  ['disturb', 'confus disarray discombob mix-up muddy', 'drowsy sleepy somnol']
# TOKENIZED WORDS:  ['hepatomega megalohepat', 'enlarg spleen', 'loss weight']
# TOKENIZED WORDS:  ['fiss pery', 'blood-stain nas', 'lymphadenopathy', 'capt control gain ict rapt seiz', 'hydrocepha hydrocephal', 'bankruptcy fail los nonstart person unsuccess', 'choroidit', 'meningit', 'dis intellect']
# TOKENIZED WORDS:  ['neurolog', 'behavio', 'cognit', 'mood']
# TOKENIZED WORDS:  ['sev', 'neck stiff']
# TOKENIZED WORDS:  ['nause', 'pain', 'be cat disgorg honk purg regurgit sick spu up vomit', 'watery']
# TOKENIZED WORDS:  ['respir sign', 'weight', '', 'hepatosplenomega', 'anaem anem gen']
# TOKENIZED WORDS:  ['disarray ment mix-up', 'conscy level reduc', 'control ict seiz', 'bily chol cross excit fret fussy irrit peev pet snap sur temp']
# TOKENIZED WORDS:  ['stiff', 'photalg photophob', 'be cat disgorg honk purg regurgit sick spu up vomit', 'febril pyrex', 'sick']
# TOKENIZED WORDS:  ['patch sca', 'area platelik', 'plaqu red', 'fold skin thigh', 'bord defin', 'an', 'blizzard effloresc foolhardy heady rash reckless roseol']
# TOKENIZED WORDS:  ['bloody sput', 'frothy', 'distress', 'tachypne', 'bronchospasm']
# TOKENIZED WORDS:  ['sor throat', 'bridg custody deal forc giv hand handwrit help hir man manpow men mit on ov pass paw play reach script turn work workforc', 'dec handl laurel med medal palm ribbon then tre wrea', 'back backtalk cav lip mou mouthpiec or rim sass speak talk ut verb', 'mala uneas uneasy', 'sor', 'appetit poor']
# TOKENIZED WORDS:  ['adenopathy reg', 'maculopapul', 'append extrem', 'febril pyrex']
# TOKENIZED WORDS:  ['blur vis', 'ail anct annoy ass both hurt in inflict nuis sens troubl', 'photophob']
# TOKENIZED WORDS:  ['', 'control ict seiz', 'behavy chang', 'febril pyrex', 'paralys part']

# %%
# reset underlying graph data
tf.reset_default_graph()
# Build neural network
net = tflearn.input_data(shape=[None, len(train_x[0])])
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, len(train_y[0]), activation='softmax')
net = tflearn.regression(net)

# Define model and setup tensorboard
model = tflearn.DNN(net, tensorboard_dir='tflearn_logs')
# Start training (apply gradient descent algorithm)
model.fit(train_x, train_y, n_epoch=10000, batch_size=8, show_metric=True)
model.save('model.tflearn')
# Out:
# Training Step: 79999  | total loss: 0.04529 | time: 0.010s
# | Adam | epoch: 20000 | loss: 0.04529 - acc: 0.9973 -- iter: 24/25
# Training Step: 80000  | total loss: 0.04183 | time: 0.014s
# | Adam | epoch: 20000 | loss: 0.04183 - acc: 0.9976 -- iter: 25/25
# --
# INFO:tensorflow:C:\Users\Steven\Documents\HTN PROJECT 2\model.tflearn is not in all_model_checkpoint_paths. Manually adding it.

# %%
# save all of our data structures
import pickle
pickle.dump( {'words':words, 'classes':classes, 'train_x':train_x, 'train_y':train_y, 'classes_details':classes_details}, open( "training_data", "wb" ) )
