# %%
# things we need for NLP
import nltk
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()
from nltk.corpus import wordnet
syns = wordnet.synsets("program")

# things we need for Tensorflow
import numpy as np
import tflearn
import tensorflow as tf
import random
import re
import unicodedata
import sys
# Out:
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)

# %%
import urllib.request
import urllib.response
import sys
import os, glob
import http.client, urllib
import json
import http.client, urllib.request, urllib.parse, urllib.error, base64

# Replace the accessKey string value with your valid access key.
accessKey = '82e4612615634c398bfd26e7d6327833'
url = 'westcentralus.api.cognitive.microsoft.com'
path = '/text/analytics/v2.0/keyPhrases'

def extract_keywords(body):
    headers = {'Ocp-Apim-Subscription-Key': accessKey}
    conn = http.client.HTTPSConnection(url)
    body_req = {'documents':[{'language': 'en', 'id': 1, 'text': body}]}
    body_json = json.dumps(body_req)
    conn.request ("POST", path, body_json, headers)
    response = conn.getresponse ()
    string = response.read().decode('utf-8')
    json_obj = json.loads(string)
    print("json_obj: ", json_obj)
    keyphrases_list = ((json_obj['documents'])[0])['keyPhrases']
    print("keyphrases_list: ", keyphrases_list)
    return keyphrases_list

# %%
# pronto needed to prase obo files
import pronto
ont = pronto.Ontology('https://raw.githubusercontent.com/DiseaseOntology/HumanDiseaseOntology/master/src/ontology/doid.obo')

# medical conditions training data
training_data = []

# adds every medical condition with listed symptoms
for term in ont:
    if "has_symptom" in term.desc:
        training_data.append({"class":term.name, "sentence":term.desc})
print ("%s total classes in training data" % len(training_data))

# chooses random 100 medical conditions with symptoms
training_data = random.sample(training_data, 25)
print ("%s randomly chosen classes in training data" % len(training_data))
for term in training_data:
    print(term["class"] + " | " + term["sentence"] )
# Out:
# 358 total classes in training data
# 25 randomly chosen classes in training data
# classical swine fever | A viral infectious disease that results_in infection in swine, has_material_basis_in Classical swine fever virus, which is transmitted_by direct contact with oronasal secretions of the infected pig, transmitted_by ingestion of contaminated food, and transmitted_by fomites. The infection has_symptom high fever, has_symptom huddling, has_symptom weakness, has_symptom drowsiness, has_symptom anorexia, has_symptom conjunctivitis, has_symptom diarrhea, and has_symptom hemorrhages in the skin.
# jejunoileitis | An inflammatory bowel disease that is characterized by patchy areas of inflammation located_in jejunum, has_symptom abdominal pain, has_symptom diarrhea, has_symptom cramps and has_symptom formation of fistulas.
# Neoscytalidium dimidiatum infectious disease | A dermatomycosis that results_in fungal infection located_in nail, has_material_basis_in Neoscytalidium dimidiatum and has_symptom rough nail, and has_symptom crumbly nail which can separate from the nail bed.
# Venezuelan hemorrhagic fever | A viral infectious disease that is a hemorrhagic fever, has_material_basis_in Guanarito virus, which is transmitted_by cotton rat, Sigmodon alstoni and transmitted_by cane mouse, Zygodontomys brevicauda. The infection has_symptom fever, has_symptom headache, has_symptom myalgia, has_symptom sore throat, has_symptom weakness, has_symptom anorexia, has_symptom nausea, has_symptom vomiting, has_symptom convulsions, has_symptom epistaxis, has_symptom bleeding gums, has_symptom hematemesis, has_symptom melena, and has_symptom menorrhagia.
# postherpetic trigeminal neuralgia | A viral infectious disease that results_in pain located_in trigeminal nerve, has_material_basis_in Human herpesvirus 3, which reactivates after the initial infection. The infection has_symptom facial pain.
# Cytomegalovirus gastritis | A Cytomegalovirus infectious disease that results_in inflammation located_in stomach lining, has_material_basis_in Human herpesvirus 5, has_symptom dyspepsia, and has_symptom nausea and vomiting.
# pseudobulbar palsy | A brain disease that is characterized by damage to neurons of the corticobulbar tract, has_symptom dysarthria, has_symptom dysphagia, has_symptom spasticity located_in tongue, has_symptom abnormal bulbar reflexes, and has_symptom emotional outbursts.
# Cytomegalovirus pneumonia | A Cytomegalovirus infectious disease that results_in inflammation, located_in lung, has_material_basis_in Human herpesvirus 5, a member of a group of herpes-type viruses especially in people who have a suppressed immune system and has_symptom cough, has_symptom fatigue, has_symptom shortness of breath, and has_symptom hypoxemia. Cytomegalovirus infection can be demonstrated microscopically by the detection of intranuclear inclusion bodies.
# Argentine hemorrhagic fever | A viral infectious disease that is a hemorrhagic fever, has_material_basis_in Junin virus, which is transmitted_by rodent, Calomys musculinus. The infection has_symptom fever, has_symptom fatigue, has_symptom malaise, has_symptom leukopenia, has_symptom thrombocytopenia, and has_symptom hemorrhagic manifestations.
# polioencephalitis | An Enterovirus infectious disease that results_in inflammation located_in brain, has_material_basis_in polioviruses, which are transmitted_by ingestion of food contaminated with feces. The infection has_symptom tremors, has_symptom nystagmus, has_symptom loss of conjugate eye movements, has_symptom muscle rigidity, has_symptom hemiparesis, and has_symptom coma.
# sennetsu fever | A primary bacterial infectious disease that results_in infection, has_material_basis_in Neorickettsia sennetsu, which is transmitted_by ingestion of raw or under-cooked gray mullet fish infected with the trematodes. The infection has_symptom fever, has_symptom malaise, has_symptom anorexia, has_symptom lymphadenopathy, has_symptom hepatosplenomegaly, has_symptom fatigue, has_symptom chills, has_symptom headache, has_symptom backache and has_symptom myalgia.
# urethral condylomata acuminata | An anogenital venereal wart that results_in infection located_in skin of urethra, has_material_basis_in human papillomaviruses (types 6 and 11), which are transmitted_by direct sexual contact with the skin of an infected partner. The infection has_symptom urethral warts.
# Varicella-zoster virus encephalitis | A Varicellovirus infectious disease that results_in infection located_in brain, has_material_basis_in Human herpesvirus 3 and has_symptom lethargy, has_symptom rash, has_symptom confusion, has_symptom hallucinations, has_symptom weakness, has_symptom paralysis, has_symptom numbness, and has_symptom parasthesias.
# Kawasaki disease | A lymphadenitis characterized by swelling of cervical lymph nodes in infants and young children and inflammation of medium-sized blood vessels located_in body, has_symptom fever, has_symptom congestion of ocular conjunctivae, has_symptom reddening of lips, has_symptom reddening of oral cavity, has_symptom protuberance of tongue papillae and has_symptom edema of extremities.
# tinea barbae | A dermatophytosis that results_in fungal infection which effects horny layer of epidermis of the bearded areas located_in face or located_in neck, has_material_basis_in Trichophyton mentagrophytes or has_material_basis_in Trichophyton verrucosum, which also effects hair, and effects nail and has_symptom inflammatory kerion-like plaques, and results_in_formation_of noninflammatory superficial perifollicular pustules.
# feline panleukopenia | A viral infectious disease that results_in ulceration located_in intestinal epithelium of cats, which has_material_basis_in Feline panleukopenia virus, transmitted_by contact with an infected cat's bodily fluids, feces, or fleas. The infection has_symptom bloody diarrhea, has_symptom dehydration, has_symptom anemia, and has_symptom vomiting.
# herpes zoster keratoconjunctivitis | An ophthalmic herpes zoster that results_in inflammation located_in cornea and located_in conjunctiva, has_material_basis_in Human herpesvirus 3, which reactivates from the trigeminal ganglion after the primary infection and has_symptom red eye, has_symptom irritation, and has_symptom pain.
# Yellow fever virus infectious disease | A Flavivirus infectious disease that results_in infection, has_material_basis_in Yellow fever virus, which is transmitted_by mosquito bites. The infection has_symptom fever, has_symptom severe headache, has_symptom back pain, has_symptom muscle ache, has_symptom nausea, and has_symptom weakness.
# West Nile fever | A viral infectious disease that results_in infection, has_material_basis_in West Nile virus, which is transmitted_by Culex and transmitted_by Aedes mosquitoes. The infection has_symptom fever, has_symptom sore throat, has_symptom headache, has_symptom body ache, has_symptom nausea, has_symptom maculopapular rash and has_symptom vomiting.
# rippling muscle disease 1 | A muscle tissue disease characterized by electrically silent contractions of the skeletal muscles in response to mechanical stimuli. It has_material_basis in mutation in the gene localized to 1q41 at the distal end of the long arm of chromosome 1, has_symptom characteristic lateral rolling movement of muscle, has_symptom muscle cramps, has_symptom muscle pain, has_symptom muscle stiffness during or following exercise.
# candidal endocarditis | A candidiasis that results_in inflammation located_in endocardium, has_material_basis_in Candida, which favors previously damaged or prosthetic heart valves. The source is often an intravascular catheter or contaminated equipment used for illicit intravenous drug injection. The illness has_symptom fever, has_symptom murmur, has_symptom congestive heart failure, has_symptom anemia, and has_symptom splenomegaly.
# herpes zoster | A viral infectious disease that results_in infection located_in nerve fiber, has_material_basis_in Human herpesvirus 3, which reactivates after appearing as chickenpox in childhood. The virus is transmitted_by direct contact with the rash, which can develop into chickenpox in newly-infected individuals. The infection has_symptom rash which is followed by blisters, has_symptom headache, has_symptom fever, has_symptom malaise, has_symptom itching, has_symptom burning pain, and has_symptom paresthesia.
# melioidosis | A primary bacterial infectious disease that results_in infection, has_material_basis_in Burkholderia pseudomallei, which is transmitted_by contact with the contaminated water or soil. The infection has_symptom fever, has_symptom respiratory distress, has_symptom chest pain, and has_symptom stomach pain.
# adenovirus meningitis | An adenovirus infectious disease that results_in inflammation located_in meninges, has_material_basis_in Human adenovirus 3 or has_material_basis_in Human adenovirus 7 and has_symptom fever, has_symptom headache, has_symptom stiff neck, and has_symptom confusion.
# acute porphyria | A porphyria that has_symptom abdominal pain, has_symptom neuropathy, has_symptom autonomic instability and has_symptom psychosis.

# %%
# a table structure to hold the different punctuation used
tbl = dict.fromkeys(i for i in range(sys.maxunicode)
                    if unicodedata.category(chr(i)).startswith('P'))

# method to remove punctuations from sentences.
# def remove_punctuation(text):
#     return text.translate(tbl)

# method to slice strings
def slicer(my_str,sub):
    index=my_str.find(sub)
    if index !=-1 :
         return my_str[index:] 
    else :
         raise Exception('Sub string not found!')

# find synonyms of all the words in a sentence
def find_syns(sentence):
    words = []
    for word in sentence:
        if word != '':
            synonyms = []
            for syn in wordnet.synsets(word):
                for l in syn.lemmas():
                    if l.name() not in synonyms and l.name() != word:
                        synonyms.append(l.name())
            word = (word + ' ' + ' '.join(synonyms)).strip()
            words.append(word)
    return words

# clean all synonyms and words
def clean_syns(arg):
    clean_synonyms = []
    for syn_set in synonyms:
        syn_set = syn_set.replace("_", " ")
        syn_set = ' '.join(s for s in syn_set.split() if not any(c.isdigit() for c in s))
        syn_set = re.sub(r'\d+', '', syn_set)
        clean_synonyms.append(syn_set)
    #print("CLEAN SYNONYMS: ",clean_synonyms)
    return clean_synonyms

# %%
import string

words = []
words_total = []
classes = []
classes_details = {}
documents = []
ignore_words = ['?', 'hassymptom']

# loop through each description per symptom
for pattern in training_data:
    #print("CLASS: " + pattern['class'])
    #print("DESCRIPTION: " + pattern['sentence'])
    #strip punctuations, numbers, and words containing numbers
    stripped = slicer(pattern['sentence'],"has_symptom")
    word_list = stripped.split()
    word_list_new = []
    for word in word_list:
        if '_' in word:
            word = 'and'
        word_list_new.append(word)
    no_punct1 = ' '.join(s for s in word_list_new)
    no_nums1 = ' '.join(s for s in no_punct1.split() if not any(c.isdigit() for c in s))
    no_nums2 = re.sub(r'\d+', '', no_nums1)
    #print("BODY: " + no_nums2)
    keywords = extract_keywords(no_nums2)
    
    #find synonyms of each word in description
    synonyms = find_syns(keywords)
    synonyms_clean = clean_syns(synonyms)
    
    # tokenize each word in the description
    w_list = []
    for syn_set in synonyms_clean:
        w_token = nltk.word_tokenize(syn_set)
        w = [stemmer.stem(i.lower()) for i in w_token if i not in ignore_words]
        w = sorted(list(set(w)))
    
        # strip duplicates
        for item in w:
            if not item in words_total and item != '':
                words_total.append(item.strip())
            else:
                w.remove(item)
    
        w_syn = ' '.join(w)
        w_list.append(w_syn)
    
    #add each string to words
    for item in w_list:
        if not item in words and item != '':
            #print("Item is in words array already.")
            words.append(item.strip())
     
    # add to documents in our corpus
    documents.append((w_list, pattern['class']))
    
    # add to our classes list
    if pattern['class'] not in classes:
        classes.append(pattern['class'])
        classes_details[pattern['class']] = pattern["sentence"].replace("_", " ")
        
#remove duplicates in words
words = sorted(list(set(words)))

# remove duplicates in classes
classes = sorted(list(set(classes)))

print (len(documents), "documents", documents)
print (len(classes), "classes", classes)
print (len(words), "unique stemmed words", words)
print ("classes_details", classes_details)
# Out:
# json_obj:  {'documents': [{'keyPhrases': ['huddling', 'anorexia', 'weakness', 'drowsiness', 'diarrhea', 'conjunctivitis'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['huddling', 'anorexia', 'weakness', 'drowsiness', 'diarrhea', 'conjunctivitis']
# json_obj:  {'documents': [{'keyPhrases': ['diarrhea', 'cramps', 'abdominal pain'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['diarrhea', 'cramps', 'abdominal pain']
# json_obj:  {'documents': [{'keyPhrases': ['rough nail', 'crumbly nail', 'nail bed'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['rough nail', 'crumbly nail', 'nail bed']
# json_obj:  {'documents': [{'keyPhrases': ['myalgia', 'bleeding gums', 'sore throat', 'epistaxis', 'convulsions', 'weakness', 'nausea', 'anorexia', 'vomiting'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['myalgia', 'bleeding gums', 'sore throat', 'epistaxis', 'convulsions', 'weakness', 'nausea', 'anorexia', 'vomiting']
# json_obj:  {'documents': [{'keyPhrases': ['facial pain'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['facial pain']
# json_obj:  {'documents': [{'keyPhrases': ['dyspepsia', 'nausea'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['dyspepsia', 'nausea']
# json_obj:  {'documents': [{'keyPhrases': ['abnormal bulbar reflexes', 'spasticity', 'tongue', 'emotional outbursts'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['abnormal bulbar reflexes', 'spasticity', 'tongue', 'emotional outbursts']
# json_obj:  {'documents': [{'keyPhrases': ['shortness of breath', 'fatigue', 'detection of intranuclear inclusion bodies', 'cough', 'hypoxemia', 'Cytomegalovirus infection'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['shortness of breath', 'fatigue', 'detection of intranuclear inclusion bodies', 'cough', 'hypoxemia', 'Cytomegalovirus infection']
# json_obj:  {'documents': [{'keyPhrases': ['thrombocytopenia', 'malaise', 'fatigue', 'leukopenia'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['thrombocytopenia', 'malaise', 'fatigue', 'leukopenia']
# json_obj:  {'documents': [{'keyPhrases': ['loss of conjugate eye movements', 'muscle rigidity', 'nystagmus', 'hemiparesis', 'tremors'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['loss of conjugate eye movements', 'muscle rigidity', 'nystagmus', 'hemiparesis', 'tremors']
# json_obj:  {'documents': [{'keyPhrases': ['anorexia', 'headache', 'lymphadenopathy', 'chills', 'hepatosplenomegaly', 'fatigue'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['anorexia', 'headache', 'lymphadenopathy', 'chills', 'hepatosplenomegaly', 'fatigue']
# json_obj:  {'documents': [{'keyPhrases': ['urethral warts'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['urethral warts']
# json_obj:  {'documents': [{'keyPhrases': ['confusion', 'weakness', 'hallucinations', 'numbness', 'rash'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['confusion', 'weakness', 'hallucinations', 'numbness', 'rash']
# json_obj:  {'documents': [{'keyPhrases': ['protuberance of tongue papillae', 'oral cavity', 'lips', 'congestion of ocular conjunctivae', 'edema of extremities', 'fever'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['protuberance of tongue papillae', 'oral cavity', 'lips', 'congestion of ocular conjunctivae', 'edema of extremities', 'fever']
# json_obj:  {'documents': [{'keyPhrases': ['plaques', 'noninflammatory superficial perifollicular pustules', 'inflammatory kerion'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['plaques', 'noninflammatory superficial perifollicular pustules', 'inflammatory kerion']
# json_obj:  {'documents': [{'keyPhrases': ['anemia', 'dehydration', 'bloody diarrhea'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['anemia', 'dehydration', 'bloody diarrhea']
# json_obj:  {'documents': [{'keyPhrases': ['irritation', 'red eye'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['irritation', 'red eye']
# json_obj:  {'documents': [{'keyPhrases': ['pain', 'nausea', 'severe headache', 'muscle ache'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['pain', 'nausea', 'severe headache', 'muscle ache']
# json_obj:  {'documents': [{'keyPhrases': ['headache', 'nausea', 'body ache', 'maculopapular rash', 'sore throat'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['headache', 'nausea', 'body ache', 'maculopapular rash', 'sore throat']
# json_obj:  {'documents': [{'keyPhrases': ['muscle pain', 'muscle cramps', 'muscle stiffness', 'characteristic lateral rolling movement of muscle', 'exercise'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['muscle pain', 'muscle cramps', 'muscle stiffness', 'characteristic lateral rolling movement of muscle', 'exercise']
# json_obj:  {'documents': [{'keyPhrases': ['congestive heart failure', 'anemia', 'murmur', 'fever'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['congestive heart failure', 'anemia', 'murmur', 'fever']
# json_obj:  {'documents': [{'keyPhrases': ['fever', 'blisters', 'itching', 'headache', 'malaise', 'pain'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['fever', 'blisters', 'itching', 'headache', 'malaise', 'pain']
# json_obj:  {'documents': [{'keyPhrases': ['chest pain', 'stomach pain', 'respiratory distress'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['chest pain', 'stomach pain', 'respiratory distress']
# json_obj:  {'documents': [{'keyPhrases': ['stiff neck', 'headache', 'fever'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['stiff neck', 'headache', 'fever']
# json_obj:  {'documents': [{'keyPhrases': ['neuropathy', 'autonomic instability', 'abdominal pain'], 'id': '1'}], 'errors': []}
# keyphrases_list:  ['neuropathy', 'autonomic instability', 'abdominal pain']
# 25 documents [(['cow huddl togeth', 'anorex', 'fail helpless impuiss weak', 'drowsy sleepy somnol', 'bowel diarrhe diarrhoe loos of the', 'conjunctivit pinkey'], 'classical swine fever'), (['diarrhe loos the', 'cramp halt hamp iron musc spasm strangle', 'abdomin pain'], 'jejunoileitis'), (['nail rough', 'crumbl', 'bed'], 'Neoscytalidium dimidiatum infectious disease'), (['myalg myodyn', 'blee gum', 'sor throat', 'epistax noseblee', 'convuls fit paroxysm turmoil upheav', 'helpless weak', 'nause sick', '', 'barf be cast cat chuck disgorg emes honk puk purg regorg regurgit retch spew spu throw up upchuck vomit'], 'Venezuelan hemorrhagic fever'), (['fac'], 'postherpetic trigeminal neuralgia'), (['dyspeps indigest stomach upset', 'sick'], 'Cytomegalovirus gastritis'), (['abnorm bulb reflex', 'spast', 'clap gloss knif langu lingu nat spit tongu', 'emot outburst'], 'pseudobulbar palsy'), (['brea short', 'down duty fag fatigu jad out outwear pal tir upon wear weary', 'body detect includ intranuclear', 'cough', 'hypoxem', 'cytomegalovir infect'], 'Cytomegalovirus pneumonia'), (['thrombocytopenia thrombopenia', 'mala uneas uneasy', 'duty fatigu out pal upon weary', 'leucopen leukopen'], 'Argentine hemorrhagic fever'), (['conjug ey loss mov', 'rigid', 'nystagm', 'hemipares', 'ear micros quak shud trem'], 'polioencephalitis'), (['', 'ach cephalalg concern head headach vex worry', 'lymphadenopathy', 'chil cool frisson gelid icy quiv shiv thrill tingl', 'hepatosplenomega', 'duty fatigu out pal upon weary'], 'sennetsu fever'), (['urethr wart'], 'urethral condylomata acuminata'), (['confus disarray discombob ment mix-up muddy', 'helpless weak', 'delud hallucin', 'apathy indiff numb spiritless', 'blizzard effloresc foolhardy heady rash reckless roseol skin'], 'Varicella-zoster virus encephalitis'), (['papilla protub', 'cav or', 'back backtalk brim lip mou rim sass talk', 'congest conjunctiva ocul', 'edem extrem', 'febr febril fev pyrex'], 'Kawasaki disease'), (['brass mem plaqu tablet', 'noninflam perifollicul pust superf', 'inflam ker'], 'tinea barbae'), (['anaem anem gen', 'dehydr desicc dry evap', 'bloody'], 'feline panleukopenia'), (['aggrav annoy both discomfort excit innerv irrit piqu provoc temp', 'red'], 'herpes zoster keratoconjunctivitis'), (['ail anct ass hurt in inflict neck nuis sens troubl', 'sick', 'sev', 'musc'], 'Yellow fever virus infectious disease'), (['cephalalg head vex', 'sick', 'body', 'maculopapul', 'throat'], 'West Nile fever'), (['pain', 'musc', 'stiff', 'charact lat musc rol', 'do dril employ exampl exerc exert phys pract recit sess us util work workout'], 'rippling muscle disease 1'), (['fail heart', 'anem', 'cardiac croak gnarl grumbl murm mussit mut vowel', 'febril pyrex'], 'candidal endocarditis'), (['febril pyrex', 'bleb blist bull scald ves whip', 'itch itchy rub scratch spoil', 'cephalalg head vex', 'uneas', 'anct ass hurt inflict nuis sens troubl'], 'herpes zoster'), (['chest', 'stomach', 'distress respir'], 'melioidosis'), (['stiff', 'cephalalg head vex', 'febril pyrex'], 'adenovirus meningitis'), (['neuropathy', 'autonom inst', 'pain'], 'acute porphyria')]
# 25 classes ['Argentine hemorrhagic fever', 'Cytomegalovirus gastritis', 'Cytomegalovirus pneumonia', 'Kawasaki disease', 'Neoscytalidium dimidiatum infectious disease', 'Varicella-zoster virus encephalitis', 'Venezuelan hemorrhagic fever', 'West Nile fever', 'Yellow fever virus infectious disease', 'acute porphyria', 'adenovirus meningitis', 'candidal endocarditis', 'classical swine fever', 'feline panleukopenia', 'herpes zoster', 'herpes zoster keratoconjunctivitis', 'jejunoileitis', 'melioidosis', 'polioencephalitis', 'postherpetic trigeminal neuralgia', 'pseudobulbar palsy', 'rippling muscle disease 1', 'sennetsu fever', 'tinea barbae', 'urethral condylomata acuminata']
# 89 unique stemmed words ['abdomin pain', 'abnorm bulb reflex', 'ach cephalalg concern head headach vex worry', 'aggrav annoy both discomfort excit innerv irrit piqu provoc temp', 'ail anct ass hurt in inflict neck nuis sens troubl', 'anaem anem gen', 'anct ass hurt inflict nuis sens troubl', 'anem', 'anorex', 'apathy indiff numb spiritless', 'autonom inst', 'back backtalk brim lip mou rim sass talk', 'barf be cast cat chuck disgorg emes honk puk purg regorg regurgit retch spew spu throw up upchuck vomit', 'bed', 'bleb blist bull scald ves whip', 'blee gum', 'blizzard effloresc foolhardy heady rash reckless roseol skin', 'bloody', 'body', 'body detect includ intranuclear', 'bowel diarrhe diarrhoe loos of the', 'brass mem plaqu tablet', 'brea short', 'cardiac croak gnarl grumbl murm mussit mut vowel', 'cav or', 'cephalalg head vex', 'charact lat musc rol', 'chest', 'chil cool frisson gelid icy quiv shiv thrill tingl', 'clap gloss knif langu lingu nat spit tongu', 'confus disarray discombob ment mix-up muddy', 'congest conjunctiva ocul', 'conjug ey loss mov', 'conjunctivit pinkey', 'convuls fit paroxysm turmoil upheav', 'cough', 'cow huddl togeth', 'cramp halt hamp iron musc spasm strangle', 'crumbl', 'cytomegalovir infect', 'dehydr desicc dry evap', 'delud hallucin', 'diarrhe loos the', 'distress respir', 'do dril employ exampl exerc exert phys pract recit sess us util work workout', 'down duty fag fatigu jad out outwear pal tir upon wear weary', 'drowsy sleepy somnol', 'duty fatigu out pal upon weary', 'dyspeps indigest stomach upset', 'ear micros quak shud trem', 'edem extrem', 'emot outburst', 'epistax noseblee', 'fac', 'fail heart', 'fail helpless impuiss weak', 'febr febril fev pyrex', 'febril pyrex', 'helpless weak', 'hemipares', 'hepatosplenomega', 'hypoxem', 'inflam ker', 'itch itchy rub scratch spoil', 'leucopen leukopen', 'lymphadenopathy', 'maculopapul', 'mala uneas uneasy', 'musc', 'myalg myodyn', 'nail rough', 'nause sick', 'neuropathy', 'noninflam perifollicul pust superf', 'nystagm', 'pain', 'papilla protub', 'red', 'rigid', 'sev', 'sick', 'sor throat', 'spast', 'stiff', 'stomach', 'throat', 'thrombocytopenia thrombopenia', 'uneas', 'urethr wart']
# classes_details {'herpes zoster': 'A viral infectious disease that results in infection located in nerve fiber, has material basis in Human herpesvirus 3, which reactivates after appearing as chickenpox in childhood. The virus is transmitted by direct contact with the rash, which can develop into chickenpox in newly-infected individuals. The infection has symptom rash which is followed by blisters, has symptom headache, has symptom fever, has symptom malaise, has symptom itching, has symptom burning pain, and has symptom paresthesia.', 'Venezuelan hemorrhagic fever': 'A viral infectious disease that is a hemorrhagic fever, has material basis in Guanarito virus, which is transmitted by cotton rat, Sigmodon alstoni and transmitted by cane mouse, Zygodontomys brevicauda. The infection has symptom fever, has symptom headache, has symptom myalgia, has symptom sore throat, has symptom weakness, has symptom anorexia, has symptom nausea, has symptom vomiting, has symptom convulsions, has symptom epistaxis, has symptom bleeding gums, has symptom hematemesis, has symptom melena, and has symptom menorrhagia.', 'classical swine fever': 'A viral infectious disease that results in infection in swine, has material basis in Classical swine fever virus, which is transmitted by direct contact with oronasal secretions of the infected pig, transmitted by ingestion of contaminated food, and transmitted by fomites. The infection has symptom high fever, has symptom huddling, has symptom weakness, has symptom drowsiness, has symptom anorexia, has symptom conjunctivitis, has symptom diarrhea, and has symptom hemorrhages in the skin.', 'feline panleukopenia': "A viral infectious disease that results in ulceration located in intestinal epithelium of cats, which has material basis in Feline panleukopenia virus, transmitted by contact with an infected cat's bodily fluids, feces, or fleas. The infection has symptom bloody diarrhea, has symptom dehydration, has symptom anemia, and has symptom vomiting.", 'urethral condylomata acuminata': 'An anogenital venereal wart that results in infection located in skin of urethra, has material basis in human papillomaviruses (types 6 and 11), which are transmitted by direct sexual contact with the skin of an infected partner. The infection has symptom urethral warts.', 'sennetsu fever': 'A primary bacterial infectious disease that results in infection, has material basis in Neorickettsia sennetsu, which is transmitted by ingestion of raw or under-cooked gray mullet fish infected with the trematodes. The infection has symptom fever, has symptom malaise, has symptom anorexia, has symptom lymphadenopathy, has symptom hepatosplenomegaly, has symptom fatigue, has symptom chills, has symptom headache, has symptom backache and has symptom myalgia.', 'Cytomegalovirus pneumonia': 'A Cytomegalovirus infectious disease that results in inflammation, located in lung, has material basis in Human herpesvirus 5, a member of a group of herpes-type viruses especially in people who have a suppressed immune system and has symptom cough, has symptom fatigue, has symptom shortness of breath, and has symptom hypoxemia. Cytomegalovirus infection can be demonstrated microscopically by the detection of intranuclear inclusion bodies.', 'Kawasaki disease': 'A lymphadenitis characterized by swelling of cervical lymph nodes in infants and young children and inflammation of medium-sized blood vessels located in body, has symptom fever, has symptom congestion of ocular conjunctivae, has symptom reddening of lips, has symptom reddening of oral cavity, has symptom protuberance of tongue papillae and has symptom edema of extremities.', 'tinea barbae': 'A dermatophytosis that results in fungal infection which effects horny layer of epidermis of the bearded areas located in face or located in neck, has material basis in Trichophyton mentagrophytes or has material basis in Trichophyton verrucosum, which also effects hair, and effects nail and has symptom i ...

# %%
# create our training data
training = []
output = []
# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    print("TOKENIZED WORDS: ",pattern_words)
    # stem each word
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    # create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# TOKENIZED WORDS:  ['cow huddl togeth', 'anorex', 'fail helpless impuiss weak', 'drowsy sleepy somnol', 'bowel diarrhe diarrhoe loos of the', 'conjunctivit pinkey']
# TOKENIZED WORDS:  ['diarrhe loos the', 'cramp halt hamp iron musc spasm strangle', 'abdomin pain']
# TOKENIZED WORDS:  ['nail rough', 'crumbl', 'bed']
# TOKENIZED WORDS:  ['myalg myodyn', 'blee gum', 'sor throat', 'epistax noseblee', 'convuls fit paroxysm turmoil upheav', 'helpless weak', 'nause sick', '', 'barf be cast cat chuck disgorg emes honk puk purg regorg regurgit retch spew spu throw up upchuck vomit']
# TOKENIZED WORDS:  ['fac']
# TOKENIZED WORDS:  ['dyspeps indigest stomach upset', 'sick']
# TOKENIZED WORDS:  ['abnorm bulb reflex', 'spast', 'clap gloss knif langu lingu nat spit tongu', 'emot outburst']
# TOKENIZED WORDS:  ['brea short', 'down duty fag fatigu jad out outwear pal tir upon wear weary', 'body detect includ intranuclear', 'cough', 'hypoxem', 'cytomegalovir infect']
# TOKENIZED WORDS:  ['thrombocytopenia thrombopenia', 'mala uneas uneasy', 'duty fatigu out pal upon weary', 'leucopen leukopen']
# TOKENIZED WORDS:  ['conjug ey loss mov', 'rigid', 'nystagm', 'hemipares', 'ear micros quak shud trem']
# TOKENIZED WORDS:  ['', 'ach cephalalg concern head headach vex worry', 'lymphadenopathy', 'chil cool frisson gelid icy quiv shiv thrill tingl', 'hepatosplenomega', 'duty fatigu out pal upon weary']
# TOKENIZED WORDS:  ['urethr wart']
# TOKENIZED WORDS:  ['confus disarray discombob ment mix-up muddy', 'helpless weak', 'delud hallucin', 'apathy indiff numb spiritless', 'blizzard effloresc foolhardy heady rash reckless roseol skin']
# TOKENIZED WORDS:  ['papilla protub', 'cav or', 'back backtalk brim lip mou rim sass talk', 'congest conjunctiva ocul', 'edem extrem', 'febr febril fev pyrex']
# TOKENIZED WORDS:  ['brass mem plaqu tablet', 'noninflam perifollicul pust superf', 'inflam ker']
# TOKENIZED WORDS:  ['anaem anem gen', 'dehydr desicc dry evap', 'bloody']
# TOKENIZED WORDS:  ['aggrav annoy both discomfort excit innerv irrit piqu provoc temp', 'red']
# TOKENIZED WORDS:  ['ail anct ass hurt in inflict neck nuis sens troubl', 'sick', 'sev', 'musc']
# TOKENIZED WORDS:  ['cephalalg head vex', 'sick', 'body', 'maculopapul', 'throat']
# TOKENIZED WORDS:  ['pain', 'musc', 'stiff', 'charact lat musc rol', 'do dril employ exampl exerc exert phys pract recit sess us util work workout']
# TOKENIZED WORDS:  ['fail heart', 'anem', 'cardiac croak gnarl grumbl murm mussit mut vowel', 'febril pyrex']
# TOKENIZED WORDS:  ['febril pyrex', 'bleb blist bull scald ves whip', 'itch itchy rub scratch spoil', 'cephalalg head vex', 'uneas', 'anct ass hurt inflict nuis sens troubl']
# TOKENIZED WORDS:  ['chest', 'stomach', 'distress respir']
# TOKENIZED WORDS:  ['stiff', 'cephalalg head vex', 'febril pyrex']
# TOKENIZED WORDS:  ['neuropathy', 'autonom inst', 'pain']

# %%
# reset underlying graph data
tf.reset_default_graph()
# Build neural network
net = tflearn.input_data(shape=[None, len(train_x[0])])
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, len(train_y[0]), activation='softmax')
net = tflearn.regression(net)

# Define model and setup tensorboard
model = tflearn.DNN(net, tensorboard_dir='tflearn_logs')
# Start training (apply gradient descent algorithm)
model.fit(train_x, train_y, n_epoch=10000, batch_size=8, show_metric=True)
model.save('model.tflearn')
# Out:
# Training Step: 39999  | total loss: 0.06476 | time: 0.011s
# | Adam | epoch: 10000 | loss: 0.06476 - acc: 0.9949 -- iter: 24/25
# Training Step: 40000  | total loss: 0.06038 | time: 0.014s
# | Adam | epoch: 10000 | loss: 0.06038 - acc: 0.9954 -- iter: 25/25
# --
# INFO:tensorflow:C:\Users\Steven\Documents\HTN Project NEW\model.tflearn is not in all_model_checkpoint_paths. Manually adding it.

# %%
# save all of our data structures
import pickle
pickle.dump( {'words':words, 'classes':classes, 'train_x':train_x, 'train_y':train_y, 'classes_details':classes_details}, open( "training_data", "wb" ) )
